# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

# Importing the numpy package, numpy is a package in Python used for Scientific Computing.
# It is used to perform various operations and going to play major role in analysing Movies dataset.
import numpy as np

# Importing the pandas package, pandas is a Python package providing fast, flexible, and expressive data structures
# designed to make working with “relational” or “labeled” data both easy and intuitive.
# It aims to be the fundamental high-level building block for doing practical, real world data analysis in Python.
import pandas as pd

#importing matplot lib for creating plots
import matplotlib.pyplot as plt

#importing seaborn lib for creating plots
import seaborn as sns

from datetime import datetime

# %% [markdown]
# ### Data Understanding :-

# %% [markdown]
# #### Columns that we have used for analysis with explanation:-
#
# id:	It is a unique ID for the loan listing.
# loan_amnt: This is the amount applied by the borrower for the loan process, ranging from 5000 to 35000 in this dataset. It has been binned with 5000 interval for analysis.
#
# funded_amnt: This is the approved loan amont. This data is similar with loan_amnt and treated similarly for analysis.( binned with 5000 interval,ranging from 5000 to 35000)
#
# term: this is the number of payments on the loan, either could be 36 or 60.
#
# int_rate: This is interest rates applied to the loan, ranging from 5%-20%. It has been binned with interval of 5.
#
# installment: This is the monthly payment owed by the borrower ranging from 20 to 1300 . After dealing with the outlayers, it has been ranged from 200 to 800, with 200 interval.
#
# grade: Loan grading is a classification system that involves assigning a quality score to a loan based on a borrower's credit history, quality of collateral and likelihood of repayment of the principal and interest. A score can also be applied to a portfolio of loans
#
# sub_grade: Each grade is further catagorised in 5 sub grade making it a1,a2,a2,a4,a5,b1,b2,b3 etc… till g5.
#
# emp_length: This is the duration of the employment of borrower ranging from 0 to 10+ years.
#
# home_ownership: IF the home is owned by the borrower or not , there are 4 type of home ownersghip in this dataset i.e. own, rent, mortgage, other.
#
# annual_inc: This is the annual income declaired by the borrower. In this data set we had data starting from 4000 to 6000000, after treating the outlayers, it has a range of 20000 to 1200000 an d is binned with an inter val of 20000.
#
# verification_status: IF the person verification is done or not, As per this dataset, there are 3 verification status i.e verified , not verified, source verified.
#
# issue_d: This is the loan issue date, we have considered each year from 2007 to 2011.
#
# loan_status: As per this dataset, loan status is the main factor of analysis . There is 3 type of status fully paid, current and chared off. Chared off is considered as default.
#
# purpose: Purpose of  the loan is consider as one of the factor of analysis. These purpose are like (credit card, car, home renovation,medical etc) . Total 14 are defined in this dataset.
#
# zip_code: Zip Code of the area.
#
# addr_state: There are 51 state in this dataset.
#
# dti: This is the Debt-to-income ratio, raning from 0 to 30 in this dataset. For analysis purpose we have binned it from less >5 to more<25 with a interval of 5.
#
# delinq_2yrs: This is the number of incidences of delinquency in the borrower's credit file, ranging from 0 to 11.
#
# inq_last_6mths: This is the number of inquiries in past 6 months, ranging from 0 to 8.
#
# open_acc: Total no of open account the person has.
#
# pub_rec: If the person has any public records.
#
# revol_bal: Total revolving credit balance the person has.
#
# revol_util:Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.
#
# total_acc: Total no of account the person has.
#
# pub_rec_bankruptcies: The public record of bankruptcies ranging from 0 to 2.

# %% [markdown]
# #### Reporting Data Issues:-
# There are 111 number of columns out of which there are 26 columns which we think that are uselful for our analyis , So will be reporting the issues for those columns which we are going to use.
#
# 1.term : It is object format and has a string attached to it. So converted it to numeric format.
#
# 2.int_rate : It is also in object format and has percentage attached to it. So converted it to numeric format.
#
# 3.emp_length: There are many issues present in it. Issue that has been solved are missing value treatment. The missing value are assigned as 0. And the values which is present as 10 > years is taken as 10 years and similary for < 1 year is taken as 1.These assumptions are done for our convinence in calculation. And it is also converted to float data type.
#
# 4.annual_inc: Here the annual income is divided by 1000 to convert them into thousand format.
#
# 5.zip_code: Zip code is reported in object format. It has XXX attached to it. So we removed the XXX and made it to numeric.
#
# 6.revol_util: The value has percentage attached to it, so it is reported in the object format. So removing the percentage and converting into the numeric format.
#
# 7.issue_d: Date and time format are reported in a wrong way which also cannot be used for analyis. So the issue_d is converted to right date format so that it can be easily used with python.
#
# 8.loan_amnt: The loan_amnt data is highly skewed , so outlier treatment is done.
#
# 9.int_rate: The int_rate data is highly skewed , so outlier treatment is done.
#
# 10.installment: The installment data is highly skewed, So outlier treatment is done.
#
# 11.annual_inc: The annual_inc data is highly skewed, So outlier treatment is done.
#
# 12.open_acc: The open_acc data is highly skewed, So outlier treatment is done.
#
# 13.revol_bal: The revol_bal data is highly skewed , So outlier treatment is done.
#
# 14.total_acc: The total_acc data is highly skewed , So outlier treatment is done.
#
# 15.revol_util: The revol_util has lots of null values, but the revol_bal is zero for all field. So the fields are assigned as 0 for the null values. If the revol_bal is zero for a person definitely the revol_util will be zero for him.
#
# 16.funded_amnt: The funded_amnt data is highly skewed. So outlier treatment is done.

# %% [markdown]
# ### Data Loading

# %%
#Reading the Data from the csv file
loan_data = pd.read_csv("C:/Users/Abinash/Downloads/loan/loan.csv")
print(loan_data.info())
loan_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB
# None
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade            ...              \
# 0   10.65%       162.87     B        B2            ...
# 1   15.27%        59.83     C        C4            ...
# 2   15.96%        84.33     C        C5            ...
# 3   13.49%       339.31     C        C1            ...
# ...

# %% [markdown]
# ### Data cleaning - drop unused columns

# %%
#removing the columns which are not used for analysis
loan_data = loan_data.drop(['member_id','funded_amnt_inv','emp_title','earliest_cr_line','pymnt_plan','url','desc','title','initial_list_status','out_prncp','out_prncp_inv','total_pymnt','total_pymnt_inv','total_rec_prncp','total_rec_int','total_rec_late_fee','recoveries','collection_recovery_fee','last_pymnt_d','last_pymnt_amnt','next_pymnt_d','collections_12_mths_ex_med','mths_since_last_major_derog','policy_code','application_type','annual_inc_joint','dti_joint','verification_status_joint','acc_now_delinq','tot_coll_amt','tot_cur_bal','open_acc_6m','open_il_6m','open_il_12m','open_il_24m','mths_since_rcnt_il','total_bal_il','il_util','open_rv_12m','open_rv_24m','max_bal_bc','all_util','total_rev_hi_lim','inq_fi','total_cu_tl','inq_last_12m','acc_open_past_24mths','avg_cur_bal','bc_open_to_buy','bc_util','chargeoff_within_12_mths','delinq_amnt','mo_sin_old_il_acct','mo_sin_old_rev_tl_op','mo_sin_rcnt_rev_tl_op','mo_sin_rcnt_tl','mort_acc','mths_since_recent_bc','mths_since_recent_bc_dlq','mths_since_recent_inq','mths_since_recent_revol_delinq','num_accts_ever_120_pd','num_actv_bc_tl','num_actv_rev_tl','num_bc_sats','num_bc_tl','num_il_tl','num_op_rev_tl','num_rev_accts','num_rev_tl_bal_gt_0','num_sats','num_tl_120dpd_2m','num_tl_30dpd','num_tl_90g_dpd_24m','num_tl_op_past_12m','pct_tl_nvr_dlq','percent_bc_gt_75','tax_liens','tot_hi_cred_lim','total_bal_ex_mort','total_bc_limit','total_il_high_credit_limit','last_credit_pull_d'], axis= 1)
print(loan_data.info())
loan_data.head
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 28 columns):
# id                        39717 non-null int64
# loan_amnt                 39717 non-null int64
# funded_amnt               39717 non-null int64
# term                      39717 non-null object
# int_rate                  39717 non-null object
# installment               39717 non-null float64
# grade                     39717 non-null object
# sub_grade                 39717 non-null object
# emp_length                38642 non-null object
# home_ownership            39717 non-null object
# annual_inc                39717 non-null float64
# verification_status       39717 non-null object
# issue_d                   39717 non-null object
# loan_status               39717 non-null object
# purpose                   39717 non-null object
# zip_code                  39717 non-null object
# addr_state                39717 non-null object
# ...

# %%
#Check for data redundancy, In the data set it is clearly mentioned that id is a unique column
loan_data.id.is_unique
# Out:
# True

# %%
#converting the required columns of data set to lower case
loan_data['grade'] = loan_data['grade'].str.lower()
loan_data['sub_grade'] = loan_data['sub_grade'].str.lower()
loan_data['home_ownership'] = loan_data['home_ownership'].str.lower()
loan_data['verification_status'] = loan_data['verification_status'].str.lower()
loan_data['loan_status'] = loan_data['loan_status'].str.lower()
loan_data['purpose'] = loan_data['purpose'].str.lower()
loan_data['addr_state'] = loan_data['addr_state'].str.lower()
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 28 columns):
# id                        39717 non-null int64
# loan_amnt                 39717 non-null int64
# funded_amnt               39717 non-null int64
# term                      39717 non-null object
# int_rate                  39717 non-null object
# installment               39717 non-null float64
# grade                     39717 non-null object
# sub_grade                 39717 non-null object
# emp_length                38642 non-null object
# home_ownership            39717 non-null object
# annual_inc                39717 non-null float64
# verification_status       39717 non-null object
# issue_d                   39717 non-null object
# loan_status               39717 non-null object
# purpose                   39717 non-null object
# zip_code                  39717 non-null object
# addr_state                39717 non-null object
# ...

# %%
#term is a quantity not a string, so foramtting it and converting into proper format
term = loan_data["term"].str.split(" ", n = 2, expand = True) 
loan_data["term"]=pd.to_numeric(term[1])
print(loan_data.info())
loan_data.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 28 columns):
# id                        39717 non-null int64
# loan_amnt                 39717 non-null int64
# funded_amnt               39717 non-null int64
# term                      39717 non-null int64
# int_rate                  39717 non-null object
# installment               39717 non-null float64
# grade                     39717 non-null object
# sub_grade                 39717 non-null object
# emp_length                38642 non-null object
# home_ownership            39717 non-null object
# annual_inc                39717 non-null float64
# verification_status       39717 non-null object
# issue_d                   39717 non-null object
# loan_status               39717 non-null object
# purpose                   39717 non-null object
# zip_code                  39717 non-null object
# addr_state                39717 non-null object
# ...

# %%
#int_rate is a quantity not a string, fotmatting it and converting to right format
int_rate = loan_data["int_rate"].str.split("%", n = 2, expand = True) 
loan_data["int_rate"]=pd.to_numeric(int_rate[0])
print(loan_data.info())
loan_data.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 28 columns):
# id                        39717 non-null int64
# loan_amnt                 39717 non-null int64
# funded_amnt               39717 non-null int64
# term                      39717 non-null int64
# int_rate                  39717 non-null float64
# installment               39717 non-null float64
# grade                     39717 non-null object
# sub_grade                 39717 non-null object
# emp_length                38642 non-null object
# home_ownership            39717 non-null object
# annual_inc                39717 non-null float64
# verification_status       39717 non-null object
# issue_d                   39717 non-null object
# loan_status               39717 non-null object
# purpose                   39717 non-null object
# zip_code                  39717 non-null object
# addr_state                39717 non-null object
# ...

# %%
#Emplength has many issue assocaited with it. It should be quantity and not string
#For ease of calculation few changes are done for example , if the emp > = 10 years converting it to 10
#Similarly for other is the person is < 1 then we have take it as 1
#There are few data's whose values are not present so assigning them with 0.
empLength = loan_data["emp_length"].str.split("y", n = 2, expand = True) 
loan_data["emp_length"] = empLength[0]
loan_data["emp_length"] = loan_data["emp_length"].str.replace("+","",regex=True)
loan_data["emp_length"] = loan_data["emp_length"].str.replace("<","",regex=True).astype(float)
loan_data.loc[pd.isnull(loan_data["emp_length"])== True , "emp_length"] = 0
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 28 columns):
# id                        39717 non-null int64
# loan_amnt                 39717 non-null int64
# funded_amnt               39717 non-null int64
# term                      39717 non-null int64
# int_rate                  39717 non-null float64
# installment               39717 non-null float64
# grade                     39717 non-null object
# sub_grade                 39717 non-null object
# emp_length                39717 non-null float64
# home_ownership            39717 non-null object
# annual_inc                39717 non-null float64
# verification_status       39717 non-null object
# issue_d                   39717 non-null object
# loan_status               39717 non-null object
# purpose                   39717 non-null object
# zip_code                  39717 non-null object
# addr_state                39717 non-null object
# ...

# %%
#Converting Money to Thousands for the ease of analysis
loan_data.annual_inc = loan_data.annual_inc/1000
print(loan_data.info())
loan_data.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 28 columns):
# id                        39717 non-null int64
# loan_amnt                 39717 non-null int64
# funded_amnt               39717 non-null int64
# term                      39717 non-null int64
# int_rate                  39717 non-null float64
# installment               39717 non-null float64
# grade                     39717 non-null object
# sub_grade                 39717 non-null object
# emp_length                39717 non-null float64
# home_ownership            39717 non-null object
# annual_inc                39717 non-null float64
# verification_status       39717 non-null object
# issue_d                   39717 non-null object
# loan_status               39717 non-null object
# purpose                   39717 non-null object
# zip_code                  39717 non-null object
# addr_state                39717 non-null object
# ...

# %%
#The zip code should be a numeric value not string, formatting it and converting to the right format
zip_value = loan_data.zip_code.str.split("x", n =1 , expand= True)
loan_data.zip_code = zip_value[0].astype(float)
print(loan_data.info())
loan_data.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 28 columns):
# id                        39717 non-null int64
# loan_amnt                 39717 non-null int64
# funded_amnt               39717 non-null int64
# term                      39717 non-null int64
# int_rate                  39717 non-null float64
# installment               39717 non-null float64
# grade                     39717 non-null object
# sub_grade                 39717 non-null object
# emp_length                39717 non-null float64
# home_ownership            39717 non-null object
# annual_inc                39717 non-null float64
# verification_status       39717 non-null object
# issue_d                   39717 non-null object
# loan_status               39717 non-null object
# purpose                   39717 non-null object
# zip_code                  39717 non-null float64
# addr_state                39717 non-null object
# ...

# %%
#revol_util is a numeric not a string, formatting it and converting to the right format
util = loan_data["revol_util"].str.split("%", n = 1, expand = True) 
loan_data["revol_util"]=pd.to_numeric(util[0])
print(loan_data.info())
loan_data.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 28 columns):
# id                        39717 non-null int64
# loan_amnt                 39717 non-null int64
# funded_amnt               39717 non-null int64
# term                      39717 non-null int64
# int_rate                  39717 non-null float64
# installment               39717 non-null float64
# grade                     39717 non-null object
# sub_grade                 39717 non-null object
# emp_length                39717 non-null float64
# home_ownership            39717 non-null object
# annual_inc                39717 non-null float64
# verification_status       39717 non-null object
# issue_d                   39717 non-null object
# loan_status               39717 non-null object
# purpose                   39717 non-null object
# zip_code                  39717 non-null float64
# addr_state                39717 non-null object
# ...

# %%
#Converting Date and Time to Proper Format
loan_data['issue_d'] =  pd.to_datetime(loan_data['issue_d'], format ='%b-%y')
print(loan_data.info())
loan_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 28 columns):
# id                        39717 non-null int64
# loan_amnt                 39717 non-null int64
# funded_amnt               39717 non-null int64
# term                      39717 non-null int64
# int_rate                  39717 non-null float64
# installment               39717 non-null float64
# grade                     39717 non-null object
# sub_grade                 39717 non-null object
# emp_length                39717 non-null float64
# home_ownership            39717 non-null object
# annual_inc                39717 non-null float64
# verification_status       39717 non-null object
# issue_d                   39717 non-null datetime64[ns]
# loan_status               39717 non-null object
# purpose                   39717 non-null object
# zip_code                  39717 non-null float64
# addr_state                39717 non-null object
# ...

# %%
#Checking the Columns for the Null Values and Null percentage
print((loan_data.isnull()).sum(axis=0))
round(loan_data.isnull().sum()/len(loan_data)*100,2)
# Out:
# id                            0
# loan_amnt                     0
# funded_amnt                   0
# term                          0
# int_rate                      0
# installment                   0
# grade                         0
# sub_grade                     0
# emp_length                    0
# home_ownership                0
# annual_inc                    0
# verification_status           0
# issue_d                       0
# loan_status                   0
# purpose                       0
# zip_code                      0
# addr_state                    0
# dti                           0
# delinq_2yrs                   0
# inq_last_6mths                0
# mths_since_last_delinq    25682
# mths_since_last_record    36931
# open_acc                      0
# pub_rec                       0
# revol_bal                     0
# revol_util                   50
# total_acc                     0
# pub_rec_bankruptcies        697
# dtype: int64
# ...

# %%
#As there are two columns which are having more than 50 percentage of null values we can drop these columns
#As there are three other columns with null values we will do data cleaning for them once we use them for analysis
loan_data = loan_data.drop(['mths_since_last_delinq','mths_since_last_record'], axis= 1)
print(loan_data.info())
loan_data.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 26 columns):
# id                      39717 non-null int64
# loan_amnt               39717 non-null int64
# funded_amnt             39717 non-null int64
# term                    39717 non-null int64
# int_rate                39717 non-null float64
# installment             39717 non-null float64
# grade                   39717 non-null object
# sub_grade               39717 non-null object
# emp_length              39717 non-null float64
# home_ownership          39717 non-null object
# annual_inc              39717 non-null float64
# verification_status     39717 non-null object
# issue_d                 39717 non-null datetime64[ns]
# loan_status             39717 non-null object
# purpose                 39717 non-null object
# zip_code                39717 non-null float64
# addr_state              39717 non-null object
# dti                     39717 non-null float64
# ...

# %% [markdown]
# ### Data cleaning - Treating Outliers and Derived Columns

# %%
#outlayer treatment for loan amount
plt.boxplot(loan_data.loan_amnt)
#From the box plot it is clear that there outliers
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20c1b518eb8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20c18f13748>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20c1b518940>],
#  'medians': [<matplotlib.lines.Line2D at 0x20c18f13f98>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20c18eaa400>],
#  'means': []}

# %%
#performing Box Plot analysis
print(loan_data.loan_amnt.describe())
iqr = np.subtract(*np.percentile(loan_data.loan_amnt, [75, 25]))
print(iqr)
lower_whisker = np.percentile(loan_data.loan_amnt, 25) - 1.5*iqr
print(lower_whisker)
upper_whisker = np.percentile(loan_data.loan_amnt, 75) + 1.5*iqr
print(upper_whisker)
#As lower_whisker is less than min value so lower_whisker is min value is 500
loan_data_clean = loan_data.loc[loan_data['loan_amnt'] <= upper_whisker]
print(loan_data_clean.info())
loan_data_clean.head()
# Out:
# count    39717.000000
# mean     11219.443815
# std       7456.670694
# min        500.000000
# 25%       5500.000000
# 50%      10000.000000
# 75%      15000.000000
# max      35000.000000
# Name: loan_amnt, dtype: float64
# 9500.0
# -8750.0
# 29250.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38487 entries, 0 to 39716
# Data columns (total 26 columns):
# id                      38487 non-null int64
# loan_amnt               38487 non-null int64
# funded_amnt             38487 non-null int64
# term                    38487 non-null int64
# int_rate                38487 non-null float64
# installment             38487 non-null float64
# grade                   38487 non-null object
# sub_grade               38487 non-null object
# emp_length              38487 non-null float64
# home_ownership          38487 non-null object
# annual_inc              38487 non-null float64
# verification_status     38487 non-null object
# ...

# %%
#outlayer treatment for dti
plt.boxplot(loan_data.dti)
#The data is not skewed
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20c20a5c908>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20c20a5ce10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20c20a5c390>],
#  'medians': [<matplotlib.lines.Line2D at 0x20c20a5a9e8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20c20a5ae10>],
#  'means': []}

# %%
#performing Box Plot analysis
print(loan_data.dti.describe())
iqr = np.subtract(*np.percentile(loan_data.dti, [75, 25]))
print(iqr)
lower_whisker = np.percentile(loan_data.dti, 25) - 1.5*iqr
print(lower_whisker)
upper_whisker = np.percentile(loan_data.dti, 75) + 1.5*iqr
print(upper_whisker)
#From the Values it is clear that all the values are inside lower_whisker and upper_whisker so there is no skewness
# Out:
# count    39717.000000
# mean        13.315130
# std          6.678594
# min          0.000000
# 25%          8.170000
# 50%         13.400000
# 75%         18.600000
# max         29.990000
# Name: dti, dtype: float64
# 10.430000000000001
# -7.475000000000003
# 34.245000000000005

# %%
#outlayer treatment for intrest rate
plt.boxplot(loan_data.int_rate)
#The data are skewed
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20c190b2fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20c19152860>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20c190b2a58>],
#  'medians': [<matplotlib.lines.Line2D at 0x20c19152d68>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20c19170518>],
#  'means': []}

# %%
#performing Box Plot analysis
print(loan_data.int_rate.describe())
iqr = np.subtract(*np.percentile(loan_data.int_rate, [75, 25]))
print(iqr)
lower_whisker = np.percentile(loan_data.int_rate, 25) - 1.5*iqr
print(lower_whisker)
upper_whisker = np.percentile(loan_data.int_rate, 75) + 1.5*iqr
print(upper_whisker)
#From the Values it is clear that all the values are inside lower_whisker but some values lies above upper_whisker so there is a skewness
loan_data_clean = loan_data_clean.loc[loan_data_clean['int_rate'] <= upper_whisker]
print(loan_data_clean.info())
loan_data_clean.head()
# Out:
# count    39717.000000
# mean        12.021177
# std          3.724825
# min          5.420000
# 25%          9.250000
# 50%         11.860000
# 75%         14.590000
# max         24.590000
# Name: int_rate, dtype: float64
# 5.34
# 1.2400000000000002
# 22.6
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38435 entries, 0 to 39716
# Data columns (total 26 columns):
# id                      38435 non-null int64
# loan_amnt               38435 non-null int64
# funded_amnt             38435 non-null int64
# term                    38435 non-null int64
# int_rate                38435 non-null float64
# installment             38435 non-null float64
# grade                   38435 non-null object
# sub_grade               38435 non-null object
# emp_length              38435 non-null float64
# home_ownership          38435 non-null object
# annual_inc              38435 non-null float64
# verification_status     38435 non-null object
# ...

# %%
#outlayer treatment for installment
plt.boxplot(loan_data_clean.installment)
#The data is highly skewed
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20c20aacef0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20c20a9bba8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20c20aacda0>],
#  'medians': [<matplotlib.lines.Line2D at 0x20c20a86438>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20c20a86860>],
#  'means': []}

# %%
#performing Box Plot analysis
print(loan_data.installment.describe())
iqr = np.subtract(*np.percentile(loan_data.installment, [75, 25]))
print(iqr)
lower_whisker = np.percentile(loan_data.installment, 25) - 1.5*iqr
print(lower_whisker)
upper_whisker = np.percentile(loan_data.installment, 75) + 1.5*iqr
print(upper_whisker)
#From the Values it is clear that all the values are inside lower_whisker but some values lies above upper_whisker so there is a skewness
loan_data_clean = loan_data_clean.loc[loan_data_clean['installment'] <= upper_whisker]
print(loan_data_clean.info())
loan_data_clean.head()
# Out:
# count    39717.000000
# mean       324.561922
# std        208.874874
# min         15.690000
# 25%        167.020000
# 50%        280.220000
# 75%        430.780000
# max       1305.190000
# Name: installment, dtype: float64
# 263.76
# -228.61999999999998
# 826.42
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37808 entries, 0 to 39716
# Data columns (total 26 columns):
# id                      37808 non-null int64
# loan_amnt               37808 non-null int64
# funded_amnt             37808 non-null int64
# term                    37808 non-null int64
# int_rate                37808 non-null float64
# installment             37808 non-null float64
# grade                   37808 non-null object
# sub_grade               37808 non-null object
# emp_length              37808 non-null float64
# home_ownership          37808 non-null object
# annual_inc              37808 non-null float64
# verification_status     37808 non-null object
# ...

# %%
#outlayer treatment for loan amount
plt.boxplot(loan_data.annual_inc)
#The data are skewed
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20c21cfccc0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20c21d64978>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20c21cfcb70>],
#  'medians': [<matplotlib.lines.Line2D at 0x20c21d64e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20c21d5a630>],
#  'means': []}

# %%
#performing Box Plot analysis
print(loan_data.annual_inc.describe())
iqr = np.subtract(*np.percentile(loan_data.annual_inc, [75, 25]))
print(iqr)
lower_whisker = np.percentile(loan_data.annual_inc, 25) - 1.5*iqr
print(lower_whisker)
upper_whisker = np.percentile(loan_data.annual_inc, 75) + 1.5*iqr
print(upper_whisker)
#From the Values it is clear that all the values are inside lower_whisker but some values lies above upper_whisker so there is a skewness
loan_data_clean = loan_data_clean.loc[loan_data_clean['annual_inc'] <= upper_whisker]
print(loan_data_clean.info())
loan_data_clean.head()
# Out:
# count    39717.000000
# mean        68.968926
# std         63.793766
# min          4.000000
# 25%         40.404000
# 50%         59.000000
# 75%         82.300000
# max       6000.000000
# Name: annual_inc, dtype: float64
# 41.895999999999994
# -22.43999999999999
# 145.144
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36392 entries, 0 to 39716
# Data columns (total 26 columns):
# id                      36392 non-null int64
# loan_amnt               36392 non-null int64
# funded_amnt             36392 non-null int64
# term                    36392 non-null int64
# int_rate                36392 non-null float64
# installment             36392 non-null float64
# grade                   36392 non-null object
# sub_grade               36392 non-null object
# emp_length              36392 non-null float64
# home_ownership          36392 non-null object
# annual_inc              36392 non-null float64
# verification_status     36392 non-null object
# ...

# %%
#outlayer treatment for open acc
plt.boxplot(loan_data.open_acc)
#The data are skewed
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20c2170afd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20c216fdc88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20c2170ae80>],
#  'medians': [<matplotlib.lines.Line2D at 0x20c216ec518>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20c216ec940>],
#  'means': []}

# %%
#Performing Box Plot analysis
print(loan_data.open_acc.describe())
iqr = np.subtract(*np.percentile(loan_data.open_acc, [75, 25]))
print(iqr)
lower_whisker = np.percentile(loan_data.open_acc, 25) - 1.5*iqr
print(lower_whisker)
upper_whisker = np.percentile(loan_data.open_acc, 75) + 1.5*iqr
print(upper_whisker)
#From the Values it is clear that all the values are inside lower_whisker but some values lies above upper_whisker so there is a skewness
loan_data_clean = loan_data_clean.loc[loan_data_clean['open_acc'] <= upper_whisker]
print(loan_data_clean.info())
loan_data_clean.head()
# Out:
# count    39717.000000
# mean         9.294408
# std          4.400282
# min          2.000000
# 25%          6.000000
# 50%          9.000000
# 75%         12.000000
# max         44.000000
# Name: open_acc, dtype: float64
# 6.0
# -3.0
# 21.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35966 entries, 0 to 39716
# Data columns (total 26 columns):
# id                      35966 non-null int64
# loan_amnt               35966 non-null int64
# funded_amnt             35966 non-null int64
# term                    35966 non-null int64
# int_rate                35966 non-null float64
# installment             35966 non-null float64
# grade                   35966 non-null object
# sub_grade               35966 non-null object
# emp_length              35966 non-null float64
# home_ownership          35966 non-null object
# annual_inc              35966 non-null float64
# verification_status     35966 non-null object
# issue_d                 35966 non-null datetime64[ns]
# ...

# %%
#outlayer treatment for revol bal
plt.boxplot(loan_data.revol_bal)
#The data are skewed
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20c20abccc0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20c21cad550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20c20abc748>],
#  'medians': [<matplotlib.lines.Line2D at 0x20c21cadda0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20c21cade80>],
#  'means': []}

# %%
#Performing Box Plot analysis
print(loan_data.revol_bal.describe())
iqr = np.subtract(*np.percentile(loan_data.revol_bal, [75, 25]))
print(iqr)
lower_whisker = np.percentile(loan_data.revol_bal, 25) - 1.5*iqr
print(lower_whisker)
upper_whisker = np.percentile(loan_data.revol_bal, 75) + 1.5*iqr
print(upper_whisker)
#From the Values it is clear that all the values are inside lower_whisker but some values lies above upper_whisker so there is a skewness
loan_data_clean = loan_data_clean.loc[loan_data_clean['open_acc'] <= upper_whisker]
print(loan_data_clean.info())
loan_data_clean.head()
# Out:
# count     39717.000000
# mean      13382.528086
# std       15885.016641
# min           0.000000
# 25%        3703.000000
# 50%        8850.000000
# 75%       17058.000000
# max      149588.000000
# Name: revol_bal, dtype: float64
# 13355.0
# -16329.5
# 37090.5
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35966 entries, 0 to 39716
# Data columns (total 26 columns):
# id                      35966 non-null int64
# loan_amnt               35966 non-null int64
# funded_amnt             35966 non-null int64
# term                    35966 non-null int64
# int_rate                35966 non-null float64
# installment             35966 non-null float64
# grade                   35966 non-null object
# sub_grade               35966 non-null object
# emp_length              35966 non-null float64
# home_ownership          35966 non-null object
# annual_inc              35966 non-null float64
# verification_status     35966 non-null object
# ...

# %%
#outlayer treatment for total acc
plt.boxplot(loan_data.total_acc)
#The data are skewed
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20c21de94a8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20c21de9cf8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20c21ddfef0>],
#  'medians': [<matplotlib.lines.Line2D at 0x20c21df2588>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20c21df29b0>],
#  'means': []}

# %%
#Perform Box Plot analysis
print(loan_data.total_acc.describe())
iqr = np.subtract(*np.percentile(loan_data.total_acc, [75, 25]))
print(iqr)
lower_whisker = np.percentile(loan_data.total_acc, 25) - 1.5*iqr
print(lower_whisker)
upper_whisker = np.percentile(loan_data.total_acc, 75) + 1.5*iqr
print(upper_whisker)
#From the Values it is clear that all the values are inside lower_whisker but some values lies above upper_whisker so there is a skewness
loan_data_clean = loan_data_clean.loc[loan_data_clean['open_acc'] <= upper_whisker]
print(loan_data_clean.info())
loan_data_clean.head()
# Out:
# count    39717.000000
# mean        22.088828
# std         11.401709
# min          2.000000
# 25%         13.000000
# 50%         20.000000
# 75%         29.000000
# max         90.000000
# Name: total_acc, dtype: float64
# 16.0
# -11.0
# 53.0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35966 entries, 0 to 39716
# Data columns (total 26 columns):
# id                      35966 non-null int64
# loan_amnt               35966 non-null int64
# funded_amnt             35966 non-null int64
# term                    35966 non-null int64
# int_rate                35966 non-null float64
# installment             35966 non-null float64
# grade                   35966 non-null object
# sub_grade               35966 non-null object
# emp_length              35966 non-null float64
# home_ownership          35966 non-null object
# annual_inc              35966 non-null float64
# verification_status     35966 non-null object
# issue_d                 35966 non-null datetime64[ns]
# ...

# %%
#In the revol util there are few data with null values , Replacing them with 0
loan_data_clean.loc[pd.isnull(loan_data_clean["revol_util"])== True , "revol_util"] = 0
loan_data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35966 entries, 0 to 39716
# Data columns (total 26 columns):
# id                      35966 non-null int64
# loan_amnt               35966 non-null int64
# funded_amnt             35966 non-null int64
# term                    35966 non-null int64
# int_rate                35966 non-null float64
# installment             35966 non-null float64
# grade                   35966 non-null object
# sub_grade               35966 non-null object
# emp_length              35966 non-null float64
# home_ownership          35966 non-null object
# annual_inc              35966 non-null float64
# verification_status     35966 non-null object
# issue_d                 35966 non-null datetime64[ns]
# loan_status             35966 non-null object
# purpose                 35966 non-null object
# zip_code                35966 non-null float64
# addr_state              35966 non-null object
# dti                     35966 non-null float64
# ...

# %%
#outlayer treatment for revol util
plt.boxplot(loan_data_clean.revol_util)
#The data is not skewed
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20c21e41cf8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20c21e49588>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20c21e41780>],
#  'medians': [<matplotlib.lines.Line2D at 0x20c21e49dd8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20c21e49eb8>],
#  'means': []}

# %%
#Perform Data analysis
print(loan_data.revol_util.describe())
iqr = np.subtract(*np.percentile(loan_data_clean.revol_util, [75, 25]))
print(iqr)
lower_whisker = np.percentile(loan_data_clean.revol_util, 25) - 1.5*iqr
print(lower_whisker)
upper_whisker = np.percentile(loan_data_clean.revol_util, 75) + 1.5*iqr
print(upper_whisker)
#From the Values it is clear that all the values are above lower_whisker and below upper_whisker so there is no skewness
# Out:
# count    39667.000000
# mean        48.832152
# std         28.332634
# min          0.000000
# 25%         25.400000
# 50%         49.300000
# 75%         72.400000
# max         99.900000
# Name: revol_util, dtype: float64
# 46.8
# -44.999999999999986
# 142.2

# %%
print(loan_data_clean.info())
# Total entries after data clean is 35966 out of total entries that is 39717. We have around 91% of data to analyze
#As our task here is to identify the defaulters so filtering the data for defaulters.
loan_data_clean_charge_off = loan_data_clean.loc[loan_data_clean["loan_status"] == "charged off"]
print(loan_data_clean_charge_off.info())
loan_data_clean_charge_off.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35966 entries, 0 to 39716
# Data columns (total 26 columns):
# id                      35966 non-null int64
# loan_amnt               35966 non-null int64
# funded_amnt             35966 non-null int64
# term                    35966 non-null int64
# int_rate                35966 non-null float64
# installment             35966 non-null float64
# grade                   35966 non-null object
# sub_grade               35966 non-null object
# emp_length              35966 non-null float64
# home_ownership          35966 non-null object
# annual_inc              35966 non-null float64
# verification_status     35966 non-null object
# issue_d                 35966 non-null datetime64[ns]
# loan_status             35966 non-null object
# purpose                 35966 non-null object
# zip_code                35966 non-null float64
# addr_state              35966 non-null object
# dti                     35966 non-null float64
# ...

# %% [markdown]
# ### Data Analysis - Univariate And Segmented Analyis for the variables

# %%
#Loan Status
#It is found that 14 percentage are charged off from the total loan distributed
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
g=sns.countplot(x="loan_status", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
paid = loan_data_clean[loan_data_clean.loan_status == 'fully paid']
print(paid.shape)
current = loan_data_clean[loan_data_clean.loan_status == 'current']
print(current.shape)
default = loan_data_clean[loan_data_clean.loan_status == 'charged off']
print(default.shape)
# Out:
# (29990, 26)
# (931, 26)
# (5045, 26)

# %%
#Taking the grade into account
#It is seen that mazor amount of loans comes under a and b
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
g = sns.countplot(x="grade", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
a = loan_data_clean[loan_data_clean.grade == 'a']
print(a.shape)
b = loan_data_clean[loan_data_clean.grade == 'b']
print(b.shape)
c = loan_data_clean[loan_data_clean.grade == 'c']
print(c.shape)
d = loan_data_clean[loan_data_clean.grade == 'd']
print(d.shape)
e = loan_data_clean[loan_data_clean.grade == 'e']
print(e.shape)
f = loan_data_clean[loan_data_clean.grade == 'f']
print(f.shape)
g = loan_data_clean[loan_data_clean.grade == 'g']
print(g.shape)
# Out:
# (9606, 26)
# (11117, 26)
# (7434, 26)
# (4632, 26)
# (2263, 26)
# (747, 26)
# (167, 26)

# %%
#Taking Sub Grade into account
#It is found the A4,B3,A5 have loans > 2500
sns.set_style('whitegrid')
plt.figure(figsize=(15,15))
g = sns.countplot(x="sub_grade", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
a1 = loan_data_clean[loan_data_clean.sub_grade == 'a1']
print(a1.shape)
a2 = loan_data_clean[loan_data_clean.sub_grade == 'a2']
print(a2.shape)
a3 = loan_data_clean[loan_data_clean.sub_grade == 'a3']
print(a3.shape)
a4 = loan_data_clean[loan_data_clean.sub_grade == 'a4']
print(a4.shape)
a5 = loan_data_clean[loan_data_clean.sub_grade == 'a5']
print(a5.shape)
b1 = loan_data_clean[loan_data_clean.sub_grade == 'b1']
print(b1.shape)
b2 = loan_data_clean[loan_data_clean.sub_grade == 'b2']
print(b2.shape)
b3 = loan_data_clean[loan_data_clean.sub_grade == 'b3']
print(b3.shape)
b4 = loan_data_clean[loan_data_clean.sub_grade == 'b4']
print(b4.shape)
b5 = loan_data_clean[loan_data_clean.sub_grade == 'b5']
print(b5.shape)
c1 = loan_data_clean[loan_data_clean.sub_grade == 'c1']
print(c1.shape)
c2 = loan_data_clean[loan_data_clean.sub_grade == 'c2']
print(c2.shape)
c3 = loan_data_clean[loan_data_clean.sub_grade == 'c3']
print(c3.shape)
c4 = loan_data_clean[loan_data_clean.sub_grade == 'c4']
print(c4.shape)
c5 = loan_data_clean[loan_data_clean.sub_grade == 'c5']
print(c5.shape)
d1 = loan_data_clean[loan_data_clean.sub_grade == 'd1']
print(d1.shape)
d2 = loan_data_clean[loan_data_clean.sub_grade == 'd2']
print(d2.shape)
d3 = loan_data_clean[loan_data_clean.sub_grade == 'd3']
print(d3.shape)
d4 = loan_data_clean[loan_data_clean.sub_grade == 'd4']
print(d4.shape)
d5 = loan_data_clean[loan_data_clean.sub_grade == 'd5']
print(d5.shape)
e1 = loan_data_clean[loan_data_clean.sub_grade == 'e1']
print(e1.shape)
e2 = loan_data_clean[loan_data_clean.sub_grade == 'e2']
print(e2.shape)
e3 = loan_data_clean[loan_data_clean.sub_grade == 'e3']
print(e3.shape)
e4 = loan_data_clean[loan_data_clean.sub_grade == 'e4']
print(e4.shape)
e5 = loan_data_clean[loan_data_clean.sub_grade == 'e5']
print(e5.shape)
f1 = loan_data_clean[loan_data_clean.sub_grade == 'f1']
print(f1.shape)
f2 = loan_data_clean[loan_data_clean.sub_grade == 'f2']
print(f2.shape)
f3 = loan_data_clean[loan_data_clean.sub_grade == 'f3']
print(f3.shape)
f4 = loan_data_clean[loan_data_clean.sub_grade == 'f4']
print(f4.shape)
f5 = loan_data_clean[loan_data_clean.sub_grade == 'f5']
print(f5.shape)
g1 = loan_data_clean[loan_data_clean.sub_grade == 'g1']
print(g1.shape)
g2 = loan_data_clean[loan_data_clean.sub_grade == 'g2']
print(g2.shape)
g3 = loan_data_clean[loan_data_clean.sub_grade == 'g3']
print(g3.shape)
g4 = loan_data_clean[loan_data_clean.sub_grade == 'g4']
print(g4.shape)
g5 = loan_data_clean[loan_data_clean.sub_grade == 'g5']
print(g5.shape)
# Out:
# (1099, 26)
# (1446, 26)
# (1744, 26)
# (2720, 26)
# (2597, 26)
# (1725, 26)
# (1925, 26)
# (2648, 26)
# (2329, 26)
# (2490, 26)
# (1950, 26)
# (1832, 26)
# (1413, 26)
# (1153, 26)
# (1086, 26)
# (829, 26)
# (1204, 26)
# (1018, 26)
# (843, 26)
# (738, 26)
# (630, 26)
# (532, 26)
# (443, 26)
# (363, 26)
# (295, 26)
# (227, 26)
# (189, 26)
# (135, 26)
# (120, 26)
# (76, 26)
# (57, 26)
# (49, 26)
# (25, 26)
# (22, 26)
# (14, 26)

# %%
#Home Ownership
#It is clear tha majority of the loans are under rent and mortgage
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
g = sns.countplot(x="home_ownership", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
rent = loan_data_clean[loan_data_clean.home_ownership == 'rent']
print(rent.shape)
own = loan_data_clean[loan_data_clean.home_ownership == 'own']
print(own.shape)
mortgage = loan_data_clean[loan_data_clean.home_ownership == 'mortgage']
print(mortgage.shape)
other = loan_data_clean[loan_data_clean.home_ownership == 'other']
print(other.shape)
none = loan_data_clean[loan_data_clean.home_ownership == 'none']
print(none.shape)
# Out:
# (17838, 26)
# (2817, 26)
# (15216, 26)
# (92, 26)
# (3, 26)

# %%
#Verification Status
#It is clear that majority of the loan given is not under verification status
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
g = sns.countplot(x="verification_status", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
verified = loan_data_clean[loan_data_clean.verification_status == 'verified']
print(verified.shape)
sc_verified = loan_data_clean[loan_data_clean.verification_status == 'source verified']
print(sc_verified.shape)
not_verified = loan_data_clean[loan_data_clean.verification_status == 'not verified']
print(not_verified.shape)
# Out:
# (10537, 26)
# (9198, 26)
# (16231, 26)

# %%
#Purpose of Loan
#It is clear that majority of loan is under debt consolidation
sns.set_style('whitegrid')
plt.figure(figsize=(20,10))
g = sns.countplot(x="purpose", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
credit_card = loan_data_clean[loan_data_clean.purpose == 'credit_card']
print(credit_card.shape)
car = loan_data_clean[loan_data_clean.purpose == 'car']
print(car.shape)
small_business = loan_data_clean[loan_data_clean.purpose == 'small_business']
print(small_business.shape)
other = loan_data_clean[loan_data_clean.purpose == 'other']
print(other.shape)
wedding = loan_data_clean[loan_data_clean.purpose == 'wedding']
print(wedding.shape)
debt_consolidation = loan_data_clean[loan_data_clean.purpose == 'debt_consolidation']
print(debt_consolidation.shape)
home_improvement = loan_data_clean[loan_data_clean.purpose == 'home_improvement']
print(home_improvement.shape)
mjr_purchase = loan_data_clean[loan_data_clean.purpose == 'major_purchase']
print(mjr_purchase.shape)
medical = loan_data_clean[loan_data_clean.purpose == 'medical']
print(medical.shape)
moving = loan_data_clean[loan_data_clean.purpose == 'moving']
print(moving.shape)
vacation = loan_data_clean[loan_data_clean.purpose == 'vacation']
print(vacation.shape)
house = loan_data_clean[loan_data_clean.purpose == 'house']
print(house.shape)
renewable_energy = loan_data_clean[loan_data_clean.purpose == 'renewable_energy']
print(renewable_energy.shape)
educational = loan_data_clean[loan_data_clean.purpose == 'educational']
print(educational.shape)
# Out:
# (4675, 26)
# (1483, 26)
# (1529, 26)
# (3713, 26)
# (890, 26)
# (16843, 26)
# (2514, 26)
# (2041, 26)
# (641, 26)
# (550, 26)
# (365, 26)
# (327, 26)
# (92, 26)
# (303, 26)

# %%
#Term
#It is clear that majority of the loan is provided under the 36 months term period
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
g = sns.countplot(x="term", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
t36 = loan_data_clean[loan_data_clean.term == 36]
print(t36.shape)
t60 = loan_data_clean[loan_data_clean.term == 60]
print(t60.shape)
# Out:
# (26821, 26)
# (9145, 26)

# %%
#Emp Length
#From the graph it is clear that majority of the loan is given to 10 years or above or less than or eaqual to 1 year
sns.set_style('whitegrid')
plt.figure(figsize=(15,15))
g = sns.countplot(x="emp_length", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
emplength_0 = loan_data_clean[loan_data_clean.emp_length == 0.0]
print(emplength_0.shape)
emplength_1 = loan_data_clean[loan_data_clean.emp_length == 1.0]
print(emplength_1.shape)
emplength_2 = loan_data_clean[loan_data_clean.emp_length == 2.0]
print(emplength_2.shape)
emplength_3 = loan_data_clean[loan_data_clean.emp_length == 3.0]
print(emplength_3.shape)
emplength_4 = loan_data_clean[loan_data_clean.emp_length == 4.0]
print(emplength_4.shape)
emplength_5 = loan_data_clean[loan_data_clean.emp_length == 5.0]
print(emplength_5.shape)
emplength_6 = loan_data_clean[loan_data_clean.emp_length == 6.0]
print(emplength_6.shape)
emplength_7 = loan_data_clean[loan_data_clean.emp_length == 7.0]
print(emplength_7.shape)
emplength_8 = loan_data_clean[loan_data_clean.emp_length == 8.0]
print(emplength_8.shape)
emplength_9 = loan_data_clean[loan_data_clean.emp_length == 9.0]
print(emplength_9.shape)
emplength_10 = loan_data_clean[loan_data_clean.emp_length == 10.0]
print(emplength_10.shape)
# Out:
# (1019, 26)
# (7255, 26)
# (4051, 26)
# (3767, 26)
# (3154, 26)
# (2990, 26)
# (2051, 26)
# (1619, 26)
# (1305, 26)
# (1130, 26)
# (7625, 26)

# %%
#delinq 2yrs
#It is cleat that people with delinq 2yrs are given more loan 
sns.set_style('whitegrid')
plt.figure(figsize=(20,10))
g = sns.countplot(x="delinq_2yrs", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
num_delinq_0 = loan_data_clean[loan_data_clean.delinq_2yrs == 0]
print(num_delinq_0.shape)
num_delinq_1 = loan_data_clean[loan_data_clean.delinq_2yrs == 1]
print(num_delinq_1.shape)
num_delinq_2 = loan_data_clean[loan_data_clean.delinq_2yrs == 2]
print(num_delinq_2.shape)
num_delinq_3 = loan_data_clean[loan_data_clean.delinq_2yrs == 3]
print(num_delinq_3.shape)
num_delinq_4 = loan_data_clean[loan_data_clean.delinq_2yrs == 4]
print(num_delinq_4.shape)
num_delinq_5 = loan_data_clean[loan_data_clean.delinq_2yrs == 5]
print(num_delinq_5.shape)
num_delinq_6 = loan_data_clean[loan_data_clean.delinq_2yrs == 6]
print(num_delinq_6.shape)
num_delinq_7 = loan_data_clean[loan_data_clean.delinq_2yrs == 7]
print(num_delinq_7.shape)
num_delinq_8 = loan_data_clean[loan_data_clean.delinq_2yrs == 8]
print(num_delinq_8.shape)
num_delinq_9 = loan_data_clean[loan_data_clean.delinq_2yrs == 9]
print(num_delinq_9.shape)
num_delinq_10 = loan_data_clean[loan_data_clean.delinq_2yrs == 10]
print(num_delinq_10.shape)
num_delinq_11 = loan_data_clean[loan_data_clean.delinq_2yrs == 11]
print(num_delinq_11.shape)
# Out:
# (32119, 26)
# (2962, 26)
# (593, 26)
# (201, 26)
# (56, 26)
# (18, 26)
# (9, 26)
# (4, 26)
# (2, 26)
# (1, 26)
# (0, 26)
# (1, 26)

# %%
#pub rec bankruptcies
#It is clear that people with 0 bankruptcies are given maximum loan
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
g = sns.countplot(x="pub_rec_bankruptcies", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %% [markdown]
# ### Data Analysis -Done by Creating Business-driven, type-driven and data-driven metrics

# %%
#Adding a new column for issue d year which contains the year only which can be used for analysis
loan_data_clean["issue_d_year"] = pd.DatetimeIndex(loan_data_clean["issue_d"]).year
print(loan_data_clean.info())
loan_data_clean
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35966 entries, 0 to 39716
# Data columns (total 27 columns):
# id                      35966 non-null int64
# loan_amnt               35966 non-null int64
# funded_amnt             35966 non-null int64
# term                    35966 non-null int64
# int_rate                35966 non-null float64
# installment             35966 non-null float64
# grade                   35966 non-null object
# sub_grade               35966 non-null object
# emp_length              35966 non-null float64
# home_ownership          35966 non-null object
# annual_inc              35966 non-null float64
# verification_status     35966 non-null object
# issue_d                 35966 non-null datetime64[ns]
# loan_status             35966 non-null object
# purpose                 35966 non-null object
# zip_code                35966 non-null float64
# addr_state              35966 non-null object
# dti                     35966 non-null float64
# ...

# %%
#Issued Year
#It is clear that maximum loans have been issued in the 2011
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
g = sns.countplot(x="issue_d_year", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
loan_2007 = loan_data_clean[loan_data_clean.issue_d_year == 2007]
print(loan_2007.shape)
loan_2008 = loan_data_clean[loan_data_clean.issue_d_year == 2008]
print(loan_2008.shape)
loan_2009 = loan_data_clean[loan_data_clean.issue_d_year == 2009]
print(loan_2009.shape)
loan_2010 = loan_data_clean[loan_data_clean.issue_d_year == 2010]
print(loan_2010.shape)
loan_2011 = loan_data_clean[loan_data_clean.issue_d_year == 2011]
print(loan_2011.shape)
# Out:
# (220, 27)
# (1449, 27)
# (4347, 27)
# (10748, 27)
# (19202, 27)

# %%
#Creating beans for loan amount for easy analysis and categorization
def loan(x):
    'creating loan range'
    if x < 5000:
        return "Less < 5000"
    elif 5000 <= x < 10000:
        return "5000-10000"
    elif 10000 <= x < 15000:
        return "10000-15000"
    elif 15000 <= x < 20000:
        return "15000-20000"
    elif 20000 <= x < 25000:
        return "20000-25000"
    elif 25000 <= x < 30000:
        return "25000-30000"
    else:
        return "More > 30000"

loan_data_clean['loan_range'] = loan_data_clean.loan_amnt.apply(lambda x: loan(x))
print(loan_data_clean.info())
loan_data_clean.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35966 entries, 0 to 39716
# Data columns (total 28 columns):
# id                      35966 non-null int64
# loan_amnt               35966 non-null int64
# funded_amnt             35966 non-null int64
# term                    35966 non-null int64
# int_rate                35966 non-null float64
# installment             35966 non-null float64
# grade                   35966 non-null object
# sub_grade               35966 non-null object
# emp_length              35966 non-null float64
# home_ownership          35966 non-null object
# annual_inc              35966 non-null float64
# verification_status     35966 non-null object
# issue_d                 35966 non-null datetime64[ns]
# loan_status             35966 non-null object
# purpose                 35966 non-null object
# zip_code                35966 non-null float64
# addr_state              35966 non-null object
# dti                     35966 non-null float64
# ...

# %%
#Loan Amount
#It is clear that maximum loan which are given was < = 5000
sns.set_style('whitegrid')
plt.figure(figsize=(15,15))
g = sns.countplot(x="loan_range", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
range_below5 = loan_data_clean[loan_data_clean.loan_range == "Less < 5000"]
print(range_below5.shape)
range_5to10 = loan_data_clean[loan_data_clean.loan_range == "5000-10000"]
print(range_5to10.shape)
range_10to15 = loan_data_clean[loan_data_clean.loan_range == "10000-15000"]
print(range_10to15.shape)
range_15to20 = loan_data_clean[loan_data_clean.loan_range == "15000-2000"]
print(range_15to20.shape)
range_20to25 = loan_data_clean[loan_data_clean.loan_range == "20000-25000"]
print(range_20to25.shape)
range_25to30 = loan_data_clean[loan_data_clean.loan_range == "25000-30000"]
print(range_25to30.shape)
range_above30 = loan_data_clean[loan_data_clean.loan_range == "More > 30000"]
print(range_above30.shape)
# Out:
# (7334, 28)
# (11783, 28)
# (8485, 28)
# (0, 28)
# (2784, 28)
# (1056, 28)
# (0, 28)

# %%
#Creating beans for total account for easy analysis by categorization the loans 
def loan(x):
    if x < 20:
        return "Less < 20"
    elif 20 <= x < 40:
        return "20-40"
    elif 40 <= x < 60:
        return "40-60"
    elif 60 <= x < 80:
        return "60-80"
    else:
        return "More > 80"

loan_data_clean['total_acc_range'] = loan_data_clean.total_acc.apply(lambda x: loan(x))
print(loan_data_clean.info())
loan_data_clean.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35966 entries, 0 to 39716
# Data columns (total 29 columns):
# id                      35966 non-null int64
# loan_amnt               35966 non-null int64
# funded_amnt             35966 non-null int64
# term                    35966 non-null int64
# int_rate                35966 non-null float64
# installment             35966 non-null float64
# grade                   35966 non-null object
# sub_grade               35966 non-null object
# emp_length              35966 non-null float64
# home_ownership          35966 non-null object
# annual_inc              35966 non-null float64
# verification_status     35966 non-null object
# issue_d                 35966 non-null datetime64[ns]
# loan_status             35966 non-null object
# purpose                 35966 non-null object
# zip_code                35966 non-null float64
# addr_state              35966 non-null object
# dti                     35966 non-null float64
# ...

# %%
#Total Account
#It is found that people who are given loans have account < 20.
sns.set_style('whitegrid')
plt.figure(figsize=(15,15))
g = sns.countplot(x="total_acc_range", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
acc_range_below20 = loan_data_clean[loan_data_clean.total_acc_range == "Less < 20"]
print(acc_range_below20.shape)
acc_range_20to40 = loan_data_clean[loan_data_clean.total_acc_range == "20-40"]
print(acc_range_20to40.shape)
acc_range_40to60 = loan_data_clean[loan_data_clean.total_acc_range == "40-60"]
print(acc_range_20to40.shape)
acc_range_60to80 = loan_data_clean[loan_data_clean.total_acc_range == "60-80"]
print(acc_range_60to80.shape)
acc_range_above80 = loan_data_clean[loan_data_clean.total_acc_range == "More > 80"]
print(acc_range_above80.shape)
# Out:
# (17760, 29)
# (15958, 29)
# (15958, 29)
# (137, 29)
# (2, 29)

# %%
#Creating beans for open account for easy analysis by categorization the loans
def loan(x):
    if x < 5:
        return "Less < 5"
    elif 5 <= x < 10:
        return "5-10"
    elif 10 <= x < 15:
        return "10-15"
    elif 15 <= x < 20:
        return "15-20"
    else:
        return "More > 20"

loan_data_clean['open_acc_range'] = loan_data_clean.open_acc.apply(lambda x: loan(x))
print(loan_data_clean.info())
loan_data_clean.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35966 entries, 0 to 39716
# Data columns (total 30 columns):
# id                      35966 non-null int64
# loan_amnt               35966 non-null int64
# funded_amnt             35966 non-null int64
# term                    35966 non-null int64
# int_rate                35966 non-null float64
# installment             35966 non-null float64
# grade                   35966 non-null object
# sub_grade               35966 non-null object
# emp_length              35966 non-null float64
# home_ownership          35966 non-null object
# annual_inc              35966 non-null float64
# verification_status     35966 non-null object
# issue_d                 35966 non-null datetime64[ns]
# loan_status             35966 non-null object
# purpose                 35966 non-null object
# zip_code                35966 non-null float64
# addr_state              35966 non-null object
# dti                     35966 non-null float64
# ...

# %%
#open account
#People have open account between 5 - 10 are given maximum loans
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
g = sns.countplot(x="open_acc_range", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
open_acc_below5 = loan_data_clean[loan_data_clean.open_acc_range == "Less < 5"]
print(open_acc_below5.shape)
open_acc_10to15 = loan_data_clean[loan_data_clean.open_acc_range == "10-15"]
print(open_acc_10to15.shape)
open_acc_15to20 = loan_data_clean[loan_data_clean.open_acc_range == "15-20"]
print(open_acc_15to20.shape)
open_acc_5to10 = loan_data_clean[loan_data_clean.open_acc_range == "5-10"]
print(open_acc_5to10.shape)
open_acc_above20 = loan_data_clean[loan_data_clean.open_acc_range == "More > 20"]
print(open_acc_above20.shape)
# Out:
# (4269, 30)
# (10383, 30)
# (3251, 30)
# (17597, 30)
# (466, 30)

# %%
#Creating beans for dti(Debt-to-income ratio) for easy analysis by categorization the loans
def loan(x):
    if x < 5:
        return "Less < 5"
    elif 5 <= x < 10:
        return "5-10"
    elif 10 <= x < 15:
        return "10-15"
    elif 15 <= x < 20:
        return "15-20"
    elif 20 <= x < 25:
        return "15-20"
    else:
        return "More > 25"

loan_data_clean['dti_range'] = loan_data_clean.dti.apply(lambda x: loan(x))
print(loan_data_clean.info())
loan_data_clean.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35966 entries, 0 to 39716
# Data columns (total 31 columns):
# id                      35966 non-null int64
# loan_amnt               35966 non-null int64
# funded_amnt             35966 non-null int64
# term                    35966 non-null int64
# int_rate                35966 non-null float64
# installment             35966 non-null float64
# grade                   35966 non-null object
# sub_grade               35966 non-null object
# emp_length              35966 non-null float64
# home_ownership          35966 non-null object
# annual_inc              35966 non-null float64
# verification_status     35966 non-null object
# issue_d                 35966 non-null datetime64[ns]
# loan_status             35966 non-null object
# purpose                 35966 non-null object
# zip_code                35966 non-null float64
# addr_state              35966 non-null object
# dti                     35966 non-null float64
# ...

# %%
#Dti range
#people with dti range between 15 - 20 are given max number of loans
sns.set_style('whitegrid')
plt.figure(figsize=(15,15))
g = sns.countplot(x="dti_range", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
dti_below5 = loan_data_clean[loan_data_clean.dti_range == "Less < 5"]
print(dti_below5.shape)
dti_5to10 = loan_data_clean[loan_data_clean.dti_range == "5-10"]
print(dti_5to10.shape)
dti_10to15 = loan_data_clean[loan_data_clean.dti_range == "10-15"]
print(dti_10to15.shape)
dti_15to20 = loan_data_clean[loan_data_clean.dti_range == "15-20"]
print(dti_15to20.shape)
dti_20to25 = loan_data_clean[loan_data_clean.dti_range == "20-25"]
print(dti_20to25.shape)
dti_above25 = loan_data_clean[loan_data_clean.dti_range == "More > 25"]
print(dti_above25.shape)
# Out:
# (4565, 31)
# (7167, 31)
# (9004, 31)
# (14598, 31)
# (0, 31)
# (632, 31)

# %%
#Creating beans for installment for easy analysis by categorization the loans
def loan(x):
    if x < 5:
        return "Less < 200"
    elif 200 <= x < 400:
        return "200-400"
    elif 400 <= x < 600:
        return "400-600"
    elif 600 <= x < 800:
        return "600-800"
    else:
        return "More > 800"

loan_data_clean['installment_range'] = loan_data_clean.installment.apply(lambda x: loan(x))
print(loan_data_clean.info())
loan_data_clean.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35966 entries, 0 to 39716
# Data columns (total 32 columns):
# id                      35966 non-null int64
# loan_amnt               35966 non-null int64
# funded_amnt             35966 non-null int64
# term                    35966 non-null int64
# int_rate                35966 non-null float64
# installment             35966 non-null float64
# grade                   35966 non-null object
# sub_grade               35966 non-null object
# emp_length              35966 non-null float64
# home_ownership          35966 non-null object
# annual_inc              35966 non-null float64
# verification_status     35966 non-null object
# issue_d                 35966 non-null datetime64[ns]
# loan_status             35966 non-null object
# purpose                 35966 non-null object
# zip_code                35966 non-null float64
# addr_state              35966 non-null object
# dti                     35966 non-null float64
# ...

# %%
#installment_range
#People who are given loan have installment range of 200 - 400
sns.set_style('whitegrid')
plt.figure(figsize=(15,15))
g = sns.countplot(x="installment_range", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
installment_below200 = loan_data_clean[loan_data_clean.installment_range == "Less < 200"]
print(installment_below200.shape)
installment_200to400 = loan_data_clean[loan_data_clean.installment_range == "200-400"]
print(installment_200to400.shape)
installment_400to600 = loan_data_clean[loan_data_clean.installment_range == "400-600"]
print(installment_400to600.shape)
installment_600to800 = loan_data_clean[loan_data_clean.installment_range == "600-800"]
print(installment_600to800.shape)
installment_above800 = loan_data_clean[loan_data_clean.installment_range == "More > 800"]
print(installment_above800.shape)
# Out:
# (0, 32)
# (14510, 32)
# (6260, 32)
# (2033, 32)
# (13163, 32)

# %%
#Creating beans for Revolving line utilization rate for easy analysis by categorization the loans
    if x < 5:
        return "Less < 20"
    elif 20 <= x < 40:
        return "20-40"
    elif 40 <= x < 60:
        return "40-60"
    elif 60 <= x < 80:
        return "60-80"
    else:
        return "More > 80"

loan_data_clean['revol_util_range'] = loan_data_clean.revol_util.apply(lambda x: loan(x))
print(loan_data_clean.info())
loan_data_clean.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35966 entries, 0 to 39716
# Data columns (total 33 columns):
# id                      35966 non-null int64
# loan_amnt               35966 non-null int64
# funded_amnt             35966 non-null int64
# term                    35966 non-null int64
# int_rate                35966 non-null float64
# installment             35966 non-null float64
# grade                   35966 non-null object
# sub_grade               35966 non-null object
# emp_length              35966 non-null float64
# home_ownership          35966 non-null object
# annual_inc              35966 non-null float64
# verification_status     35966 non-null object
# issue_d                 35966 non-null datetime64[ns]
# loan_status             35966 non-null object
# purpose                 35966 non-null object
# zip_code                35966 non-null float64
# addr_state              35966 non-null object
# dti                     35966 non-null float64
# ...

# %%
#revol util range
#People with more than 80 percentage are given maximum no of loans
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
g = sns.countplot(x="revol_util_range", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
revol_util_below20 = loan_data_clean[loan_data_clean.revol_util_range == "Less < 20"]
print(revol_util_below20.shape)
revol_util_20to40 = loan_data_clean[loan_data_clean.revol_util_range == "20-40"]
print(revol_util_20to40.shape)
revol_util_40to60 = loan_data_clean[loan_data_clean.revol_util_range == "40-60"]
print(revol_util_40to60.shape)
revol_util_60to80 = loan_data_clean[loan_data_clean.revol_util_range == "60-80"]
print(revol_util_60to80.shape)
revol_util_above80 = loan_data_clean[loan_data_clean.revol_util_range == "More > 80"]
print(revol_util_above80.shape)
# Out:
# (2480, 33)
# (7288, 33)
# (7837, 33)
# (7472, 33)
# (10889, 33)

# %%
#Creating beans for Interest Rate for easy analysis by categorization the loans
def loan(x):
    if x < 5:
        return "Less < 5"
    elif 5 <= x < 10:
        return "5-10"
    elif 10 <= x < 15:
        return "10-15"
    elif 15 <= x < 20:
        return "15-20"
    else:
        return "More > 20"


loan_data_clean['int_rate_range'] = loan_data_clean.int_rate.apply(lambda x: loan(x))
print(loan_data_clean.info())
loan_data_clean.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35966 entries, 0 to 39716
# Data columns (total 34 columns):
# id                      35966 non-null int64
# loan_amnt               35966 non-null int64
# funded_amnt             35966 non-null int64
# term                    35966 non-null int64
# int_rate                35966 non-null float64
# installment             35966 non-null float64
# grade                   35966 non-null object
# sub_grade               35966 non-null object
# emp_length              35966 non-null float64
# home_ownership          35966 non-null object
# annual_inc              35966 non-null float64
# verification_status     35966 non-null object
# issue_d                 35966 non-null datetime64[ns]
# loan_status             35966 non-null object
# purpose                 35966 non-null object
# zip_code                35966 non-null float64
# addr_state              35966 non-null object
# dti                     35966 non-null float64
# ...

# %%
#int rate range
#Maximum intrest that is charged is 10 - 15 percentage
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
g = sns.countplot(x="int_rate_range", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
int_rate_below5 = loan_data_clean[loan_data_clean.int_rate_range == "Less < 5"]
print(int_rate_below5.shape)
int_rate_10to15 = loan_data_clean[loan_data_clean.int_rate_range == "10-15"]
print(int_rate_10to15.shape)
int_rate_15to20 = loan_data_clean[loan_data_clean.int_rate_range == "15-20"]
print(int_rate_15to20.shape)
int_rate_5to10 = loan_data_clean[loan_data_clean.int_rate_range == "5-10"]
print(int_rate_5to10.shape)
int_rate_above20 = loan_data_clean[loan_data_clean.int_rate_range == "More > 20"]
print(int_rate_above20.shape)
# Out:
# (0, 34)
# (17490, 34)
# (6425, 34)
# (11537, 34)
# (514, 34)

# %%
#Creating beans for Annual income for easy analysis by categorization the loans
def loan(x):
    if x < 20:
        return "Less < 20"
    elif 20 <= x < 40:
        return "20-40"
    elif 40 <= x < 60:
        return "40-60"
    elif 60 <= x < 80:
        return "60-80"
    elif 80 <= x < 100:
        return "80-100"
    elif 100 <= x < 120:
        return "100-120"
    else:
        return "More > 120"

loan_data_clean['annual_inc_range'] = loan_data_clean.annual_inc.apply(lambda x: loan(x))
print(loan_data_clean.info())
loan_data_clean.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35966 entries, 0 to 39716
# Data columns (total 35 columns):
# id                      35966 non-null int64
# loan_amnt               35966 non-null int64
# funded_amnt             35966 non-null int64
# term                    35966 non-null int64
# int_rate                35966 non-null float64
# installment             35966 non-null float64
# grade                   35966 non-null object
# sub_grade               35966 non-null object
# emp_length              35966 non-null float64
# home_ownership          35966 non-null object
# annual_inc              35966 non-null float64
# verification_status     35966 non-null object
# issue_d                 35966 non-null datetime64[ns]
# loan_status             35966 non-null object
# purpose                 35966 non-null object
# zip_code                35966 non-null float64
# addr_state              35966 non-null object
# dti                     35966 non-null float64
# ...

# %%
#Annual Income
#People with annula income 40 k to 60 k were given max no of loans.
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
g = sns.countplot(x="annual_inc_range", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
annual_inc_below20 = loan_data_clean[loan_data_clean.annual_inc_range == "Less < 20"]
print(annual_inc_below20.shape)
annual_inc_20to40 = loan_data_clean[loan_data_clean.annual_inc_range == "20-40"]
print(annual_inc_20to40.shape)
annual_inc_40to60 = loan_data_clean[loan_data_clean.annual_inc_range == "40-60"]
print(annual_inc_40to60.shape)
annual_inc_60to80 = loan_data_clean[loan_data_clean.annual_inc_range == "60-80"]
print(annual_inc_60to80.shape)
annual_inc_80to100 = loan_data_clean[loan_data_clean.annual_inc_range == "80-100"]
print(annual_inc_80to100.shape)
annual_inc_100to120 = loan_data_clean[loan_data_clean.annual_inc_range == "100-120"]
print(annual_inc_100to120.shape)
annual_inc_above120 = loan_data_clean[loan_data_clean.annual_inc_range == "More > 120"]
print(annual_inc_above120.shape)
# Out:
# (1064, 35)
# (7889, 35)
# (10761, 35)
# (8193, 35)
# (4369, 35)
# (2078, 35)
# (1612, 35)

# %%
#Creating beans for revolving balance for easy analysis by categorization the loans
def loan(x):
    if x < 20000:
        return "Less < 20000"
    elif 20000 <= x < 40000:
        return "20000-40000"
    elif 40000 <= x < 60000:
        return "40000-60000"
    elif 60000 <= x < 80000:
        return "60000-80000"
    elif 80000 <= x < 100000:
        return "80000-100000"
    elif 100000 <= x < 120000:
        return "100000-120000"
    else:
        return "More > 120000"

loan_data_clean['revol_bal_range'] = loan_data_clean.revol_bal.apply(lambda x: loan(x))
print(loan_data_clean.info())
loan_data_clean.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35966 entries, 0 to 39716
# Data columns (total 36 columns):
# id                      35966 non-null int64
# loan_amnt               35966 non-null int64
# funded_amnt             35966 non-null int64
# term                    35966 non-null int64
# int_rate                35966 non-null float64
# installment             35966 non-null float64
# grade                   35966 non-null object
# sub_grade               35966 non-null object
# emp_length              35966 non-null float64
# home_ownership          35966 non-null object
# annual_inc              35966 non-null float64
# verification_status     35966 non-null object
# issue_d                 35966 non-null datetime64[ns]
# loan_status             35966 non-null object
# purpose                 35966 non-null object
# zip_code                35966 non-null float64
# addr_state              35966 non-null object
# dti                     35966 non-null float64
# ...

# %%
#revol bal range
#people whose revol bal is below 20K are given maximum no of loans
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
g = sns.countplot(x="revol_bal_range", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
revol_bal_below20K = loan_data_clean[loan_data_clean.revol_bal_range == "Less < 20000"]
print(revol_bal_below20K.shape)
revol_bal_20Kto40K = loan_data_clean[loan_data_clean.revol_bal_range == "20000-40000"]
print(revol_bal_20Kto40K.shape)
revol_bal_40Kto60K = loan_data_clean[loan_data_clean.revol_bal_range == "40000-60000"]
print(revol_bal_40Kto60K.shape)
revol_bal_60Kto80K = loan_data_clean[loan_data_clean.revol_bal_range == "60000-80000"]
print(revol_bal_60Kto80K.shape)
revol_bal_80Kto100K = loan_data_clean[loan_data_clean.revol_bal_range == "80000-100000"]
print(revol_bal_80Kto100K.shape)
revol_bal_100Kto120K = loan_data_clean[loan_data_clean.revol_bal_range == "100000-120000"]
print(revol_bal_100Kto120K.shape)
revol_bal_above120K = loan_data_clean[loan_data_clean.revol_bal_range == "More > 120000"]
print(revol_bal_above120K.shape)
# Out:
# (30020, 36)
# (4590, 36)
# (848, 36)
# (307, 36)
# (117, 36)
# (53, 36)
# (31, 36)

# %%
#Creating beans for funded amount for easy analysis by categorization the loans
def loan(x):
    'creating loan range'
    if x < 5000:
        return "Less < 5000"
    elif 5000 <= x < 10000:
        return "5000-10000"
    elif 10000 <= x < 15000:
        return "10000-15000"
    elif 15000 <= x < 20000:
        return "15000-20000"
    elif 20000 <= x < 25000:
        return "20000-25000"
    elif 25000 <= x < 30000:
        return "25000-30000"
    else:
        return "More > 30000"

loan_data_clean['funded_range'] = loan_data_clean.funded_amnt.apply(lambda x: loan(x))
print(loan_data_clean.info())
loan_data_clean.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35966 entries, 0 to 39716
# Data columns (total 37 columns):
# id                      35966 non-null int64
# loan_amnt               35966 non-null int64
# funded_amnt             35966 non-null int64
# term                    35966 non-null int64
# int_rate                35966 non-null float64
# installment             35966 non-null float64
# grade                   35966 non-null object
# sub_grade               35966 non-null object
# emp_length              35966 non-null float64
# home_ownership          35966 non-null object
# annual_inc              35966 non-null float64
# verification_status     35966 non-null object
# issue_d                 35966 non-null datetime64[ns]
# loan_status             35966 non-null object
# purpose                 35966 non-null object
# zip_code                35966 non-null float64
# addr_state              35966 non-null object
# dti                     35966 non-null float64
# ...

# %%
#funded range
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
g = sns.countplot(x="funded_range", data=loan_data_clean)

# Data labeling 
for p in g.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    g.annotate('{:.0f}'.format(y), (x.mean(), y),
                ha='center', va='bottom',rotation=360) # set the alignment of the text
plt.show()

# %%
funded_below5K = loan_data_clean[loan_data_clean.funded_range == "Less < 5000"]
print(funded_below5K.shape)
funded_5Kto10K = loan_data_clean[loan_data_clean.funded_range == "5000-10000"]
print(funded_5Kto10K.shape)
funded_10Kto15K = loan_data_clean[loan_data_clean.funded_range == "10000-15000"]
print(funded_10Kto15K.shape)
funded_15Kto20K = loan_data_clean[loan_data_clean.funded_range == "15000-2000"]
print(funded_15Kto20K.shape)
funded_20Kto25K = loan_data_clean[loan_data_clean.funded_range == "20000-25000"]
print(funded_20Kto25K.shape)
funded_25Kto30K = loan_data_clean[loan_data_clean.funded_range == "25000-30000"]
print(funded_25Kto30K.shape)
funded_above30K = loan_data_clean[loan_data_clean.funded_range == "More > 30000"]
print(funded_above30K.shape)
# Out:
# (7427, 37)
# (12049, 37)
# (8676, 37)
# (0, 37)
# (2492, 37)
# (794, 37)
# (0, 37)

# %% [markdown]
# #### From the above analyis it is clear that there are many variable which can be used as driver variable ( Variable which are strong indicator of default) some of the variables are :-
# grade
#
# sub_grade
#
# home_ownership
#
# verification_status
#
# purpose
#
# term
#
# emp_length
#
# delinq_2yrs
#
# pub_rec_bankruptcies
#
# loan_amnt
#
# open_acc
#
# total_acc
#
# dti
#
# installment
#
# revol_util
#
# int_rate
#
# annual_inc
#
# revol_bal

# %% [markdown]
# ### Data Analysis - Bivariate , Creating Bivariate Analysis by using the above variables

# %%
#Bivariate Analysis
loan_data_clean_charge_off.head(5)
# Out:
#          id  loan_amnt  funded_amnt  term  int_rate  installment grade  \
# 1   1077430       2500         2500    60     15.27        59.83     c
# 8   1071795       5600         5600    60     21.28       152.39     f
# 9   1071570       5375         5375    60     12.69       121.45     b
# 12  1064687       9000         9000    36     13.49       305.38     c
# 14  1069057      10000        10000    36     10.65       325.74     b
#
#    sub_grade  emp_length home_ownership          ...           addr_state  \
# 1         c4         1.0           rent          ...                   ga
# 8         f2         4.0            own          ...                   ca
# 9         b5         1.0           rent          ...                   tx
# 12        c1         1.0           rent          ...                   va
# 14        b2         3.0           rent          ...                   ca
#
#       dti delinq_2yrs inq_last_6mths open_acc  pub_rec revol_bal  revol_util  \
# ...

# %%
#As we are only taking into consideration the charged off status so filtering the data set to get only the charged off data
loan_data_clean_charge_off = loan_data_clean.loc[loan_data_clean["loan_status"] == "charged off"]
print(loan_data_clean_charge_off.info())
loan_data_clean_charge_off.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5045 entries, 1 to 39688
# Data columns (total 37 columns):
# id                      5045 non-null int64
# loan_amnt               5045 non-null int64
# funded_amnt             5045 non-null int64
# term                    5045 non-null int64
# int_rate                5045 non-null float64
# installment             5045 non-null float64
# grade                   5045 non-null object
# sub_grade               5045 non-null object
# emp_length              5045 non-null float64
# home_ownership          5045 non-null object
# annual_inc              5045 non-null float64
# verification_status     5045 non-null object
# issue_d                 5045 non-null datetime64[ns]
# loan_status             5045 non-null object
# purpose                 5045 non-null object
# zip_code                5045 non-null float64
# addr_state              5045 non-null object
# dti                     5045 non-null float64
# ...

# %%
#Bivariate Analysis 
#Term with Loan_Status
#It is found from the graph that people with term 36 months have a greater chance of being a defaulter
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.catplot(x = "loan_status", hue = "term", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_36term  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["term"] == 36)]
len(charged_off_36term.index)
# Out:
# 2968

# %%
charged_off_36term  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["term"] == 60)]
len(charged_off_36term.index)
# Out:
# 2077

# %%
#Grade with Loan_Status
#From the below plot it can be infered that people belonging to b are more prone to defaulter followed by c and d.
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.catplot(x = "loan_status", hue = "grade", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_grade_a  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["grade"] == "a")]
len(charged_off_grade_a.index)
# Out:
# 589

# %%
charged_off_grade_b  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["grade"] == "b")]
len(charged_off_grade_b.index)
# Out:
# 1338

# %%
charged_off_grade_c  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["grade"] == "c")]
len(charged_off_grade_c.index)
# Out:
# 1260

# %%
charged_off_grade_d  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["grade"] == "d")]
len(charged_off_grade_d.index)
# Out:
# 998

# %%
charged_off_grade_e  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["grade"] == "e")]
len(charged_off_grade_e.index)
# Out:
# 577

# %%
charged_off_grade_f  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["grade"] == "f")]
len(charged_off_grade_f.index)
# Out:
# 228

# %%
charged_off_grade_g  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["grade"] == "g")]
len(charged_off_grade_g.index)
# Out:
# 55

# %%
#Employment length with Loan_Status
#From the below plot it can be infered that people having work experience more than 10 years and less than 1 year have greater chance of being defaulter
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "emp_length", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_emp_l0  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["emp_length"] == 0.0)]
print(len(charged_off_emp_l0.index))
charged_off_emp_l1  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["emp_length"] == 1.0)]
print(len(charged_off_emp_l1.index))
charged_off_emp_l2  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["emp_length"] == 2.0)]
print(len(charged_off_emp_l2.index))
charged_off_emp_l3  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["emp_length"] == 3.0)]
print(len(charged_off_emp_l3.index))
charged_off_emp_l4  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["emp_length"] == 4.0)]
print(len(charged_off_emp_l4.index))
charged_off_emp_l5  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["emp_length"] == 5.0)]
print(len(charged_off_emp_l5.index))
charged_off_emp_l6  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["emp_length"] == 6.0)]
print(len(charged_off_emp_l6.index))
charged_off_emp_l7  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["emp_length"] == 7.0)]
print(len(charged_off_emp_l7.index))
charged_off_emp_l8  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["emp_length"] == 8.0)]
print(len(charged_off_emp_l8.index))
charged_off_emp_l9  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["emp_length"] == 9.0)]
print(len(charged_off_emp_l9.index))
charged_off_emp_l10  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["emp_length"] == 10.0)]
print(len(charged_off_emp_l10.index))
# Out:
# 217
# 1004
# 522
# 501
# 415
# 412
# 282
# 231
# 179
# 145
# 1137

# %%
#Home ownership with Loan_Status
#From the below plot it can be infered that people who have taken home as rented have a higher chance of being a defaulter followed by mortgage
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "home_ownership", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_rent  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["home_ownership"] == "rent")]
print(len(charged_off_rent.index))
charged_off_own  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["home_ownership"] == "own")]
print(len(charged_off_own.index))
charged_off_mortgage  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["home_ownership"] == "mortgage")]
print(len(charged_off_mortgage.index))
charged_off_other  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["home_ownership"] == "other")]
print(len(charged_off_other.index))
# Out:
# 2642
# 410
# 1977
# 16

# %%
#Verification status with Loan_Status
#From the below plot it can be infered that people who are not verified have a greater chance of being deafulter.
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "verification_status", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_source_verified  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["verification_status"] == "source verified")]
print(len(charged_off_source_verified.index))
charged_off_verified  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["verification_status"] == "verified")]
print(len(charged_off_verified.index))
charged_off_not_verified  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["verification_status"] == "not verified")]
print(len(charged_off_not_verified.index))
# Out:
# 1316
# 1687
# 2042

# %%
#Purpose with Loan_Status
#From the below plot it can be infered that people who are taking loan for debt consolidation have the greatest chance of being a defaulter.
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "purpose", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_credit_card = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["purpose"] == "credit_card")]
print(len(charged_off_credit_card.index))
charged_off_car = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["purpose"] == "car")]
print(len(charged_off_car.index))
charged_off_small_business = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["purpose"] == "small_business")]
print(len(charged_off_small_business.index))
charged_off_other = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["purpose"] == "other")]
print(len(charged_off_other.index))
charged_off_wedding = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["purpose"] == "wedding")]
print(len(charged_off_wedding.index))
charged_off_debt_consolidation = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["purpose"] == "debt_consolidation")]
print(len(charged_off_debt_consolidation.index))
charged_off_home_improvement = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["purpose"] == "home_improvement")]
print(len(charged_off_home_improvement.index))
charged_off_major_purchase = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["purpose"] == "major_purchase")]
print(len(charged_off_major_purchase.index))
charged_off_medical = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["purpose"] == "medical")]
print(len(charged_off_medical.index))
charged_off_moving = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["purpose"] == "moving")]
print(len(charged_off_moving.index))
charged_off_vacation = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["purpose"] == "vacation")]
print(len(charged_off_vacation.index))
charged_off_house = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["purpose"] == "house")]
print(len(charged_off_house.index))
charged_off_renewable_energy = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["purpose"] == "renewable_energy")]
print(len(charged_off_renewable_energy.index))
charged_off_educational = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["purpose"] == "educational")]
print(len(charged_off_educational.index))
# Out:
# 490
# 156
# 391
# 575
# 89
# 2472
# 303
# 209
# 100
# 89
# 52
# 50
# 17
# 52

# %%
#Incidences of delinquency with loan status
#From the below plot it can be infered that people having 0 delinq 2 years have a greater chance of being a defaulter
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "delinq_2yrs", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_delinq_0  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["delinq_2yrs"] == 0.0)]
print(len(charged_off_delinq_0.index))
charged_off_delinq_1  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["delinq_2yrs"] == 1.0)]
print(len(charged_off_delinq_1.index))
charged_off_delinq_2  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["delinq_2yrs"] == 2.0)]
print(len(charged_off_delinq_2.index))
charged_off_delinq_3  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["delinq_2yrs"] == 3.0)]
print(len(charged_off_delinq_3.index))
charged_off_delinq_4  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["delinq_2yrs"] == 4.0)]
print(len(charged_off_delinq_4.index))
charged_off_delinq_5  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["delinq_2yrs"] == 5.0)]
print(len(charged_off_delinq_5.index))
charged_off_delinq_6  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["delinq_2yrs"] == 6.0)]
print(len(charged_off_delinq_6.index))
charged_off_delinq_7  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["delinq_2yrs"] == 7.0)]
print(len(charged_off_delinq_7.index))
charged_off_delinq_8  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["delinq_2yrs"] == 8.0)]
print(len(charged_off_delinq_8.index))
# Out:
# 4434
# 452
# 110
# 32
# 12
# 2
# 1
# 1
# 1

# %%
#Number of inquiries in past 6 months with loan status
#From the below plot it can be infered that people who have done 0 enquiries within last 6 months have a greater chance of being a defaulter
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "inq_last_6mths", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_inq_0  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["inq_last_6mths"] == 0.0)]
print(len(charged_off_inq_0.index))
charged_off_inq_1  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["inq_last_6mths"] == 1.0)]
print(len(charged_off_inq_1.index))
charged_off_inq_2  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["inq_last_6mths"] == 2.0)]
print(len(charged_off_inq_2.index))
charged_off_inq_3  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["inq_last_6mths"] == 3.0)]
print(len(charged_off_inq_3.index))
charged_off_inq_4  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["inq_last_6mths"] == 4.0)]
print(len(charged_off_inq_4.index))
charged_off_inq_5  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["inq_last_6mths"] == 5.0)]
print(len(charged_off_inq_5.index))
charged_off_inq_6  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["inq_last_6mths"] == 6.0)]
print(len(charged_off_inq_6.index))
charged_off_inq_7  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["inq_last_6mths"] == 7.0)]
print(len(charged_off_inq_7.index))
charged_off_inq_8  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["inq_last_6mths"] == 8.0)]
print(len(charged_off_inq_8.index))
# Out:
# 2071
# 1491
# 849
# 542
# 45
# 21
# 14
# 9
# 3

# %%
#Derogatory public records with loan status
#From the below plot it can be infered that people who have no public records have a greater chance of being a defaulter
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "pub_rec", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_rec_0  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["pub_rec"] == 0.0)]
print(len(charged_off_rec_0.index))
charged_off_rec_1  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["pub_rec"] == 1.0)]
print(len(charged_off_rec_1.index))
charged_off_rec_2  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["pub_rec"] == 2.0)]
print(len(charged_off_rec_2.index))
# Out:
# 4613
# 422
# 10

# %%
#Public record of bankruptcies with loan status
#From the below plot it can be infered that people who have 0 bankruptcies have a greter chance of being a defaulter.
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "pub_rec_bankruptcies", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_bankruptcies_0  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["pub_rec_bankruptcies"] == 0.0)]
print(len(charged_off_bankruptcies_0.index))
charged_off_bankruptcies_1  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["pub_rec_bankruptcies"] == 1.0)]
print(len(charged_off_bankruptcies_1.index))
charged_off_bankruptcies_2  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["pub_rec_bankruptcies"] == 2.0)]
print(len(charged_off_bankruptcies_2.index))
# Out:
# 4603
# 337
# 2

# %%
#Loan issued year with loan status
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "issue_d_year", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_2007  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["issue_d_year"] == 2007)]
print(len(charged_off_2007.index))
charged_off_2008  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["issue_d_year"] == 2008)]
print(len(charged_off_2008.index))
charged_off_2009  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["issue_d_year"] == 2009)]
print(len(charged_off_2009.index))
charged_off_2010  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["issue_d_year"] == 2010)]
print(len(charged_off_2010.index))
charged_off_2011  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["issue_d_year"] == 2011)]
print(len(charged_off_2011.index))
# Out:
# 38
# 220
# 545
# 1377
# 2865

# %%
#loan range with loan status
#From the below plot it can be infered that people who have taken loan within 5000-10000 have a greater chance of being a defaulter.
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "loan_range", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_loan_below5K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["loan_range"] == "Less < 5000")]
print(len(charged_off_loan_below5K.index))
charged_off_loan_5Kto10K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["loan_range"] == "5000-10000")]
print(len(charged_off_loan_5Kto10K.index))
charged_off_loan_10Kto15K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["loan_range"] == "10000-15000")]
print(len(charged_off_loan_10Kto15K.index))
charged_off_loan_15Kto20K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["loan_range"] == "15000-20000")]
print(len(charged_off_loan_15Kto20K.index))
charged_off_loan_20Kto25K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["loan_range"] == "20000-25000")]
print(len(charged_off_loan_20Kto25K.index))
charged_off_loan_25Kto30K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["loan_range"] == "25000-30000")]
print(len(charged_off_loan_25Kto30K.index))
charged_off_above30K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["loan_range"] == "More < 30000")]
print(len(charged_off_above30K.index))
# Out:
# 1001
# 1527
# 1109
# 747
# 451
# 210
# 0

# %%
#Total account range with loan status
#From the below plot it can be infered that people who have total account less than 20 have a greater chance of being a defaulter
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "total_acc_range", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_acc_below20  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["total_acc_range"] == "Less < 20")]
print(len(charged_off_acc_below20.index))
charged_off_acc_20to40  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["total_acc_range"] == "20-40")]
print(len(charged_off_acc_20to40.index))
charged_off_acc_40to60  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["total_acc_range"] == "40-60")]
print(len(charged_off_acc_40to60.index))
charged_off_acc_60to80  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["total_acc_range"] == "60-80")]
print(len(charged_off_acc_60to80.index))
charged_off_acc_above80  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["total_acc_range"] == "More > 80")]
print(len(charged_off_acc_above80.index))
# Out:
# 2663
# 2083
# 278
# 21
# 0

# %%
#open account with loan status
#From the below plot it can be infered that people who have 5 to 10 open account have a greater chance of being a defaulter
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "open_acc_range", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_open_acc_below5  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["open_acc_range"] == "Less < 5")]
print(len(charged_off_open_acc_below5.index))
charged_off_open_acc_5to10  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["open_acc_range"] == "5-10")]
print(len(charged_off_open_acc_5to10.index))
charged_off_open_acc_10to15  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["open_acc_range"] == "10-15")]
print(len(charged_off_open_acc_10to15.index))
charged_off_open_acc_15to20  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["open_acc_range"] == "15-20")]
print(len(charged_off_open_acc_15to20.index))
charged_off_open_acc_above20  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["open_acc_range"] == "More > 20")]
print(len(charged_off_open_acc_above20.index))
# Out:
# 706
# 2403
# 1440
# 426
# 70

# %%
#dti range with loan status
#From the below plot it can be infered that people who have dti range between 15-20 have a greater chance of being a defaulter
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "dti_range", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_dti_below5  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["dti_range"] == "Less < 5")]
print(len(charged_off_dti_below5.index))
charged_off_dti_5to10  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["dti_range"] == "5-10")]
print(len(charged_off_dti_5to10.index))
charged_off_dti_10to15  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["dti_range"] == "10-15")]
print(len(charged_off_dti_10to15.index))
charged_off_dti_15to20  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["dti_range"] == "15-20")]
print(len(charged_off_dti_15to20.index))
charged_off_dti_20to25  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["dti_range"] == "20-25")]
print(len(charged_off_dti_20to25.index))
charged_off_dti_above25  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["dti_range"] == "More > 25")]
print(len(charged_off_dti_above25.index))
# Out:
# 559
# 873
# 1262
# 2274
# 0
# 77

# %%
#instalment range with loan status
#From the below plot it can be infered that people who have installment between 200-400 have a greater chance of being a defaulter followed by more than > 800
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "installment_range", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_installment_below200  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["installment_range"] == "Less < 200")]
print(len(charged_off_installment_below200.index))
charged_off_installment_200to400  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["installment_range"] == "200-400")]
print(len(charged_off_installment_200to400.index))
charged_off_installment_400to600  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["installment_range"] == "400-600")]
print(len(charged_off_installment_400to600.index))
charged_off_installment_600to800  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["installment_range"] == "600-800")]
print(len(charged_off_installment_600to800.index))
charged_off_installment_above800  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["installment_range"] == "More > 800")]
print(len(charged_off_installment_above800.index))
# Out:
# 0
# 1986
# 965
# 302
# 1792

# %%
#Revolving line utilization rate with loan status
#From the below plot it can be infered that people whose revol util range is more than 80 have a greater chance of being a defaulter
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "revol_util_range", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_revol_util_below20  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["revol_util_range"] == "Less < 20")]
print(len(charged_off_revol_util_below20.index))
charged_off_revol_util_20to40  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["revol_util_range"] == "20-40")]
print(len(charged_off_revol_util_20to40.index))
charged_off_revol_util_40to60  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["revol_util_range"] == "40-60")]
print(len(charged_off_revol_util_40to60.index))
charged_off_revol_util_60to80  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["revol_util_range"] == "60-80")]
print(len(charged_off_revol_util_60to80.index))
charged_off_revol_util_above80  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["revol_util_range"] == "More > 80")]
print(len(charged_off_revol_util_above80.index))
# Out:
# 293
# 841
# 1092
# 1220
# 1599

# %%
#intrest rate with loan status
#People whose intrest range is with in 10 - 15 percentage have a greater chance of being a defaulter
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.catplot(x = "loan_status", hue = "int_rate_range", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_int_rate_below5  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["int_rate_range"] == "Less < 5")]
print(len(charged_off_int_rate_below5.index))
charged_off_int_rate_5to10  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["int_rate_range"] == "5-10")]
print(len(charged_off_int_rate_5to10.index))
charged_off_int_rate_10to15  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["int_rate_range"] == "10-15")]
print(len(charged_off_int_rate_10to15.index))
charged_off_int_rate_15to20  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["int_rate_range"] == "15-20")]
print(len(charged_off_int_rate_15to20.index))
charged_off_int_rate_above20  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["int_rate_range"] == "More > 20")]
print(len(charged_off_int_rate_above20.index))
# Out:
# 0
# 776
# 2553
# 1532
# 184

# %%
#Annual income with loan status
#People whose annual income is within the range of 40 k to 60 k have a greater chance of being a defaulter followed by 20 k to 40 k
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.catplot(x = "loan_status", hue = "annual_inc_range", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_annual_inc_below20  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["annual_inc_range"] == "Less < 20")]
print(len(charged_off_annual_inc_below20.index))
charged_off_annual_inc_20to40  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["annual_inc_range"] == "20-40")]
print(len(charged_off_annual_inc_20to40.index))
charged_off_annual_inc_40to60  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["annual_inc_range"] == "40-60")]
print(len(charged_off_annual_inc_40to60.index))
charged_off_annual_inc_60to80  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["annual_inc_range"] == "60-80")]
print(len(charged_off_annual_inc_60to80.index))
charged_off_annual_inc_80to100  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["annual_inc_range"] == "80-100")]
print(len(charged_off_annual_inc_80to100.index))
charged_off_annual_inc_100to120  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["annual_inc_range"] == "100-120")]
print(len(charged_off_annual_inc_100to120.index))
charged_off_annual_inc_above120  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["annual_inc_range"] == "More > 120")]
print(len(charged_off_annual_inc_above120.index))
# Out:
# 226
# 1360
# 1582
# 1080
# 470
# 171
# 156

# %%
#revolving balance with loan status
#People whose revol balance is less than 20000 have a greater chance of being a defaulter 
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.catplot(x = "loan_status", hue = "revol_bal_range", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_revol_bal_below20K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["revol_bal_range"] == "Less < 20000")]
print(len(charged_off_revol_bal_below20K.index))
charged_off_revol_bal_20Kto40K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["revol_bal_range"] == "20000-40000")]
print(len(charged_off_revol_bal_20Kto40K.index))
charged_off_revol_bal_40Kto60K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["revol_bal_range"] == "40000-60000")]
print(len(charged_off_revol_bal_40Kto60K.index))
charged_off_revol_bal_60Kto80K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["revol_bal_range"] == "60000-80000")]
print(len(charged_off_revol_bal_60Kto80K.index))
charged_off_revol_bal_80Kto100K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["revol_bal_range"] == "80000-100000")]
print(len(charged_off_revol_bal_80Kto100K.index))
charged_off_revol_bal_100Kto120K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["revol_bal_range"] == "100000-120000")]
print(len(charged_off_revol_bal_100Kto120K.index))
charged_off_revol_bal_above120K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["revol_bal_range"] == "More > 120000")]
print(len(charged_off_revol_bal_above120K.index))
# Out:
# 4183
# 660
# 143
# 29
# 18
# 9
# 3

# %%
#funded amount with loan status
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.catplot(x = "loan_status", hue = "funded_range", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_funded_below5K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["funded_range"] == "Less < 5000")]
print(len(charged_off_funded_below5K.index))
charged_off_funded_5Kto10K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["funded_range"] == "5000-10000")]
print(len(charged_off_funded_5Kto10K.index))
charged_off_funded_10Kto15K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["funded_range"] == "10000-15000")]
print(len(charged_off_funded_10Kto15K.index))
charged_off_funded_15Kto20K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["funded_range"] == "15000-20000")]
print(len(charged_off_funded_15Kto20K.index))
charged_off_funded_20Kto25K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["funded_range"] == "20000-25000")]
print(len(charged_off_funded_20Kto25K.index))
charged_off_funded_25Kto30K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["funded_range"] == "25000-30000")]
print(len(charged_off_funded_25Kto30K.index))
charged_off_funded_above30K  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["funded_range"] == "More < 30000")]
print(len(charged_off_funded_above30K.index))
# Out:
# 1018
# 1559
# 1146
# 764
# 406
# 152
# 0

# %%
#sub grade with loan status
#People who belong to b5 sub grade have a greater chance of being a defaulter than any other sub grade.
sns.set_style('whitegrid')
plt.figure(figsize=(15,15))
sns.catplot(x = "loan_status", hue = "sub_grade", data = loan_data_clean_charge_off, kind = "count")

# %%
#sub grade of a
charged_off_grade_a1  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "a1")]
print(len(charged_off_grade_a1.index))
charged_off_grade_a2  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "a2")]
print(len(charged_off_grade_a2.index))
charged_off_grade_a3  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "a3")]
print(len(charged_off_grade_a3.index))
charged_off_grade_a4  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "a4")]
print(len(charged_off_grade_a4.index))
charged_off_grade_a5  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "a5")]
print(len(charged_off_grade_a5.index))
# Out:
# 30
# 73
# 102
# 172
# 212

# %%
#sub grade of b
charged_off_grade_b1  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "b1")]
print(len(charged_off_grade_b1.index))
charged_off_grade_b2  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "b2")]
print(len(charged_off_grade_b2.index))
charged_off_grade_b3  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "b3")]
print(len(charged_off_grade_b3.index))
charged_off_grade_b4  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "b4")]
print(len(charged_off_grade_b4.index))
charged_off_grade_b5  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "b5")]
print(len(charged_off_grade_b5.index))
# Out:
# 165
# 213
# 312
# 309
# 339

# %%
#sub grade of c
charged_off_grade_c1  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "c1")]
print(len(charged_off_grade_c1.index))
charged_off_grade_c2  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "c2")]
print(len(charged_off_grade_c2.index))
charged_off_grade_c3  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "c3")]
print(len(charged_off_grade_c3.index))
charged_off_grade_c4  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "c4")]
print(len(charged_off_grade_c4.index))
charged_off_grade_c5  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "c5")]
print(len(charged_off_grade_c5.index))
# Out:
# 308
# 301
# 252
# 202
# 197

# %%
#sub grade of d
charged_off_grade_d1  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "d1")]
print(len(charged_off_grade_d1.index))
charged_off_grade_d2  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "d2")]
print(len(charged_off_grade_d2.index))
charged_off_grade_d3  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "d3")]
print(len(charged_off_grade_d3.index))
charged_off_grade_d4  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "d4")]
print(len(charged_off_grade_d4.index))
charged_off_grade_d5  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "d5")]
print(len(charged_off_grade_d5.index))
# Out:
# 152
# 252
# 219
# 195
# 180

# %%
#sub grade of e
charged_off_grade_e1  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "e1")]
print(len(charged_off_grade_e1.index))
charged_off_grade_e2  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "e2")]
print(len(charged_off_grade_e2.index))
charged_off_grade_e3  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "e3")]
print(len(charged_off_grade_e3.index))
charged_off_grade_e4  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "e4")]
print(len(charged_off_grade_e4.index))
charged_off_grade_e5  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "e5")]
print(len(charged_off_grade_e5.index))
# Out:
# 160
# 133
# 101
# 105
# 78

# %%
#sub grade of f
charged_off_grade_f1  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "f1")]
print(len(charged_off_grade_f1.index))
charged_off_grade_f2  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "f2")]
print(len(charged_off_grade_f2.index))
charged_off_grade_f3  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "f3")]
print(len(charged_off_grade_f3.index))
charged_off_grade_f4  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "f4")]
print(len(charged_off_grade_f4.index))
charged_off_grade_f5  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "f5")]
print(len(charged_off_grade_f5.index))
# Out:
# 57
# 57
# 39
# 36
# 39

# %%
#sub grade of g
charged_off_grade_g1  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "g1")]
print(len(charged_off_grade_g1.index))
charged_off_grade_g2  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "g2")]
print(len(charged_off_grade_g2.index))
charged_off_grade_g3  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "g3")]
print(len(charged_off_grade_g3.index))
charged_off_grade_g4  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "g4")]
print(len(charged_off_grade_g4.index))
charged_off_grade_g5  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["sub_grade"] == "g5")]
print(len(charged_off_grade_g5.index))
# Out:
# 18
# 18
# 9
# 6
# 4

# %%
#Address state with loan status
#People who belong to california have a greater chance of being a defaulter than any other state.
sns.set_style('whitegrid')
plt.figure(figsize=(15,15))
sns.catplot(x = "loan_status", hue = "addr_state", data = loan_data_clean_charge_off, kind = "count")

# %%
charged_off_az  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "az")]
print(len(charged_off_az.index))
charged_off_ga  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "ga")]
print(len(charged_off_ga.index))
charged_off_il  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "il")]
print(len(charged_off_il.index))
charged_off_ca  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "ca")]
print(len(charged_off_ca.index))
charged_off_or  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "or")]
print(len(charged_off_or.index))
charged_off_nc  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "nc")]
print(len(charged_off_nc.index))
charged_off_tx  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "tx")]
print(len(charged_off_tx.index))
charged_off_va  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "va")]
print(len(charged_off_va.index))
charged_off_mo  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "mo")]
print(len(charged_off_mo.index))
charged_off_ct  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "ct")]
print(len(charged_off_ct.index))
charged_off_ut  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "ut")]
print(len(charged_off_ut.index))
charged_off_fl  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "fl")]
print(len(charged_off_fl.index))
charged_off_ny = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "ny")]
print(len(charged_off_ny.index))
charged_off_pa  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "pa")]
print(len(charged_off_pa.index))
charged_off_mn  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "mn")]
print(len(charged_off_mn.index))
charged_off_nj  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "nj")]
print(len(charged_off_nj.index))
charged_off_ky  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "ky")]
print(len(charged_off_ky.index))
charged_off_oh  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "oh")]
print(len(charged_off_oh.index))
charged_off_sc  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "sc")]
print(len(charged_off_sc.index))
charged_off_ri  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "ri")]
print(len(charged_off_ri.index))
charged_off_la  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "la")]
print(len(charged_off_la.index))
charged_off_ma  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "ma")]
print(len(charged_off_ma.index))
charged_off_wa  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "wa")]
print(len(charged_off_wa.index))
charged_off_wi  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "wi")]
print(len(charged_off_wi.index))
charged_off_al  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "al")]
print(len(charged_off_al.index))
charged_off_co  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "co")]
print(len(charged_off_co.index))
charged_off_ks  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "ks")]
print(len(charged_off_ks.index))
charged_off_nv  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "nv")]
print(len(charged_off_nv.index))
charged_off_ak  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "ak")]
print(len(charged_off_ak.index))
charged_off_md  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "md")]
print(len(charged_off_md.index))
charged_off_wv  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "wv")]
print(len(charged_off_wv.index))
charged_off_vt  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "vt")]
print(len(charged_off_vt.index))
charged_off_mi  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "mi")]
print(len(charged_off_mi.index))
charged_off_dc  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "dc")]
print(len(charged_off_dc.index))
charged_off_sd  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "sd")]
print(len(charged_off_sd.index))
charged_off_nh  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "nh")]
print(len(charged_off_nh.index))
charged_off_ar  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "ar")]
print(len(charged_off_ar.index))
charged_off_nm  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "nm")]
print(len(charged_off_nm.index))
charged_off_mt  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "mt")]
print(len(charged_off_mt.index))
charged_off_hi  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "hi")]
print(len(charged_off_hi.index))
charged_off_wy  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "wy")]
print(len(charged_off_wy.index))
charged_off_ok  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "ok")]
print(len(charged_off_ok.index))
charged_off_de  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "de")]
print(len(charged_off_de.index))
charged_off_ms  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "ms")]
print(len(charged_off_ms.index))
charged_off_tn  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "tn")]
print(len(charged_off_tn.index))
charged_off_ia  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "ia")]
print(len(charged_off_ia.index))
charged_off_ne  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "ne")]
print(len(charged_off_ne.index))
charged_off_id  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "id")]
print(len(charged_off_id.index))
charged_off_in  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "in")]
print(len(charged_off_in.index))
charged_off_me  = loan_data_clean.loc[(loan_data_clean["loan_status"] == "charged off") & (loan_data_clean["addr_state"] == "me")]
print(len(charged_off_me.index))
# Out:
# 111
# 196
# 177
# 1004
# 67
# 107
# 264
# 156
# 109
# 87
# 31
# 452
# 437
# 166
# 76
# 249
# 43
# 134
# 60
# 24
# 49
# 141
# 115
# 57
# 48
# 88
# 26
# 96
# 13
# 144
# 20
# 6
# 93
# 11
# 12
# 23
# 26
# 29
# 9
# 28
# 3
# 39
# 11
# 2
# 2
# 0
# 3
# 1
# 0
# 0

# %% [markdown]
# #### From the above analysis it clear that how the driver variable are connected with the defaulters.

# %% [markdown]
# ### Data Analysis - The condition of the driver variable are affected by various factors.  Inorder to see the effect of the Driver Variable we perform an anlysis where a person has applied for a Loan Amount range 10000-15000.

# %%
#Lets some one has applied for loan which is in between 10000 to 15000 thousand what are the condition that he will become a defaulter.
loan_data_clean_charge_off_10000_15000 = loan_data_clean_charge_off.loc[loan_data_clean_charge_off.loan_range == "10000-15000"]
print(loan_data_clean_charge_off_10000_15000.info())
loan_data_clean_charge_off_10000_15000.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1109 entries, 14 to 39601
# Data columns (total 37 columns):
# id                      1109 non-null int64
# loan_amnt               1109 non-null int64
# funded_amnt             1109 non-null int64
# term                    1109 non-null int64
# int_rate                1109 non-null float64
# installment             1109 non-null float64
# grade                   1109 non-null object
# sub_grade               1109 non-null object
# emp_length              1109 non-null float64
# home_ownership          1109 non-null object
# annual_inc              1109 non-null float64
# verification_status     1109 non-null object
# issue_d                 1109 non-null datetime64[ns]
# loan_status             1109 non-null object
# purpose                 1109 non-null object
# zip_code                1109 non-null float64
# addr_state              1109 non-null object
# dti                     1109 non-null float64
# ...

# %%
#When the person applies for a loan he selects the tenure of the loan. So first checking for the tenure.
#From the graph it is clear that if he takes for 36 month there is a more chance of defaulter.
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.catplot(x = "loan_status", hue = "term", data = loan_data_clean_charge_off_10000_15000, kind = "count")

# %%
#From above it is clear that is a person chooses a tenure of 36 months he has a greater chance of being a defaulter
#Lets dig further what are other causes that might lead to a person defaulter when he chooses 36 months tenure.
#Taking the grade of a person into consideration
#If the person belowngs to B grade there is a greater chance of being a defaulter
loan_data_clean_charge_off_10000_15000 = loan_data_clean_charge_off_10000_15000.loc[loan_data_clean_charge_off_10000_15000.term == 36]
print(loan_data_clean_charge_off_10000_15000.info())
sns.set_style('whitegrid')
plt.figure(figsize=(10,10))
sns.catplot(x = "loan_status", hue = "grade", data = loan_data_clean_charge_off_10000_15000, kind = "count")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 612 entries, 14 to 39601
# Data columns (total 37 columns):
# id                      612 non-null int64
# loan_amnt               612 non-null int64
# funded_amnt             612 non-null int64
# term                    612 non-null int64
# int_rate                612 non-null float64
# installment             612 non-null float64
# grade                   612 non-null object
# sub_grade               612 non-null object
# emp_length              612 non-null float64
# home_ownership          612 non-null object
# annual_inc              612 non-null float64
# verification_status     612 non-null object
# issue_d                 612 non-null datetime64[ns]
# loan_status             612 non-null object
# purpose                 612 non-null object
# zip_code                612 non-null float64
# addr_state              612 non-null object
# dti                     612 non-null float64
# delinq_2yrs             612 non-null int64
# ...

# %%
#From above it is clear that is a person chooses a tenure of 36 months and belongs to B grade has a greater chance of being a defaulter
#Lets dig further what are other causes that might lead to a person defaulter.
#Taking the sub grade of a person into consideration
#If the person belowngs to B5 sub grade there is a greater chance of being a defaulter
loan_data_clean_charge_off_10000_15000 = loan_data_clean_charge_off_10000_15000.loc[loan_data_clean_charge_off_10000_15000.grade == "b"]
print(loan_data_clean_charge_off_10000_15000.info())
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "sub_grade", data = loan_data_clean_charge_off_10000_15000, kind = "count")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 184 entries, 14 to 39534
# Data columns (total 37 columns):
# id                      184 non-null int64
# loan_amnt               184 non-null int64
# funded_amnt             184 non-null int64
# term                    184 non-null int64
# int_rate                184 non-null float64
# installment             184 non-null float64
# grade                   184 non-null object
# sub_grade               184 non-null object
# emp_length              184 non-null float64
# home_ownership          184 non-null object
# annual_inc              184 non-null float64
# verification_status     184 non-null object
# issue_d                 184 non-null datetime64[ns]
# loan_status             184 non-null object
# purpose                 184 non-null object
# zip_code                184 non-null float64
# addr_state              184 non-null object
# dti                     184 non-null float64
# delinq_2yrs             184 non-null int64
# ...

# %%
#From above it is clear that is a person chooses a tenure of 36 months , belongs to B grade and B5 subgrade
#has a greater chance of being a defaulter
#Lets dig further what are other causes that might lead to a person defaulter.
#Taking the emp length of a person into consideration
#If the emp working length is > or = 10, <= 2 , <= 3 years have a greater chance of being defaulter.
loan_data_clean_charge_off_10000_15000 = loan_data_clean_charge_off_10000_15000.loc[loan_data_clean_charge_off_10000_15000.sub_grade == "b5"]
print(loan_data_clean_charge_off_10000_15000.info())
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "emp_length", data = loan_data_clean_charge_off_10000_15000, kind = "count")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 231 to 39534
# Data columns (total 37 columns):
# id                      43 non-null int64
# loan_amnt               43 non-null int64
# funded_amnt             43 non-null int64
# term                    43 non-null int64
# int_rate                43 non-null float64
# installment             43 non-null float64
# grade                   43 non-null object
# sub_grade               43 non-null object
# emp_length              43 non-null float64
# home_ownership          43 non-null object
# annual_inc              43 non-null float64
# verification_status     43 non-null object
# issue_d                 43 non-null datetime64[ns]
# loan_status             43 non-null object
# purpose                 43 non-null object
# zip_code                43 non-null float64
# addr_state              43 non-null object
# dti                     43 non-null float64
# delinq_2yrs             43 non-null int64
# ...

# %%
#From above it is clear that is a person chooses a tenure of 36 months , belongs to B grade, B5 subgrade , emp working >= 10, <= 2, <= 3 years
#has a greater chance of being a defaulter
#Lets dig further what are other causes that might lead to a person defaulter.
#Taking the home ownership of a person into consideration
#Lets assume the person has <= 2 years experience
#If the person is a rented one there is a greater chance of being a defaulter
loan_data_clean_charge_off_10000_15000 = loan_data_clean_charge_off_10000_15000.loc[loan_data_clean_charge_off_10000_15000.emp_length == 2]
print(loan_data_clean_charge_off_10000_15000.info())

sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "home_ownership", data = loan_data_clean_charge_off_10000_15000, kind = "count")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 231 to 35755
# Data columns (total 37 columns):
# id                      7 non-null int64
# loan_amnt               7 non-null int64
# funded_amnt             7 non-null int64
# term                    7 non-null int64
# int_rate                7 non-null float64
# installment             7 non-null float64
# grade                   7 non-null object
# sub_grade               7 non-null object
# emp_length              7 non-null float64
# home_ownership          7 non-null object
# annual_inc              7 non-null float64
# verification_status     7 non-null object
# issue_d                 7 non-null datetime64[ns]
# loan_status             7 non-null object
# purpose                 7 non-null object
# zip_code                7 non-null float64
# addr_state              7 non-null object
# dti                     7 non-null float64
# delinq_2yrs             7 non-null int64
# ...

# %%
#From above it is clear that is a person chooses a tenure of 36 months , belongs to B grade, B5 subgrade , emp working <= 2 and has rented
#has a greater chance of being a defaulter
#Lets dig further what are other causes that might lead to a person defaulter.
#Taking the verification status of the loan for the person into consideration
loan_data_clean_charge_off_10000_15000 = loan_data_clean_charge_off_10000_15000.loc[loan_data_clean_charge_off_10000_15000.home_ownership == "rent"]
print(loan_data_clean_charge_off_10000_15000.info())
#IF the person source is not verified he has a greater chance of being a defaulter
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "verification_status", data = loan_data_clean_charge_off_10000_15000, kind = "count")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 231 to 35755
# Data columns (total 37 columns):
# id                      6 non-null int64
# loan_amnt               6 non-null int64
# funded_amnt             6 non-null int64
# term                    6 non-null int64
# int_rate                6 non-null float64
# installment             6 non-null float64
# grade                   6 non-null object
# sub_grade               6 non-null object
# emp_length              6 non-null float64
# home_ownership          6 non-null object
# annual_inc              6 non-null float64
# verification_status     6 non-null object
# issue_d                 6 non-null datetime64[ns]
# loan_status             6 non-null object
# purpose                 6 non-null object
# zip_code                6 non-null float64
# addr_state              6 non-null object
# dti                     6 non-null float64
# delinq_2yrs             6 non-null int64
# ...

# %%
#From above it is clear that is a person chooses a tenure of 36 months , belongs to B grade, B5 subgrade , emp working <= 2 and has rented house
#has a greater chance of being a defaulter
#Lets dig further what are other causes that might lead to a person defaulter.
#Taking the purpose of the loan for the person into consideration
loan_data_clean_charge_off_10000_15000 = loan_data_clean_charge_off_10000_15000.loc[loan_data_clean_charge_off_10000_15000.home_ownership == "rent"]
print(loan_data_clean_charge_off_10000_15000.info())
#If the person is taking the loan for debt consolidation he is a greater chance of being a defaulter
sns.set_style('whitegrid')
sns.catplot(x = "loan_status", hue = "purpose", data = loan_data_clean_charge_off_10000_15000, kind = "count")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 231 to 35755
# Data columns (total 37 columns):
# id                      6 non-null int64
# loan_amnt               6 non-null int64
# funded_amnt             6 non-null int64
# term                    6 non-null int64
# int_rate                6 non-null float64
# installment             6 non-null float64
# grade                   6 non-null object
# sub_grade               6 non-null object
# emp_length              6 non-null float64
# home_ownership          6 non-null object
# annual_inc              6 non-null float64
# verification_status     6 non-null object
# issue_d                 6 non-null datetime64[ns]
# loan_status             6 non-null object
# purpose                 6 non-null object
# zip_code                6 non-null float64
# addr_state              6 non-null object
# dti                     6 non-null float64
# delinq_2yrs             6 non-null int64
# ...

# %% [markdown]
# #### In the above senerio i have taken only 7 driver variables , so if the person applies for the loan and falls on the assumption we have taken into account then his loan is going to be rejected, from this it is also clear that there can be many ways in which the driver variables change their behaviour depending on the situation , So when the user applies for a loan we can go through the driver variable to check if he will be defaulter or not
